# %% [markdown]
# ## Question Answering using Deep Learning Baseline RNN LSTM Model
#
# Modified codebase from: Question Answering NLP with character-levelRNN https://github.com/yfletberliac/Mango.

# %%
import sys
import re
import tarfile
from functools import reduce
from itertools import chain
import os
from six.moves import urllib

import numpy as np
import tensorflow as tf
from tensorflow.python.ops import variable_scope as vs

# %%
BABI_DATASET_URL = 'https://s3.amazonaws.com/text-datasets/babi_tasks_1-20_v1-2.tar.gz'
DATASET_PATH = './babi'

# %%
def fetch_data(dataset_download_url=BABI_DATASET_URL, save_dataset_path=DATASET_PATH): 
    if not os.path.isdir(save_dataset_path):
        os.makedirs(save_dataset_path)
    tar_file_path = os.path.join(save_dataset_path, 'babi_tasks_data_1_20_v1.2.tar.gz')
    urllib.request.urlretrieve(dataset_download_url, tar_file_path)
    babi_tar_file = tarfile.open(tar_file_path)
    babi_tar_file.extractall(path=DATASET_PATH)
    babi_tar_file.close()

# %%
#fetch_data(dataset_download_url=BABI_DATASET_URL, save_dataset_path=DATASET_PATH)

# %%
class Config:
    """Holds model hyperparams and data information.
    Model objects are passed a Config() object at instantiation.
    """
    def __init__(self):
        pass

    batch_size = 128
    embed_size = 80
    hidden_size = 80
    max_epochs = 256
    dropout = 0.9
    lr = 0.001
    L2 = 0.001
    
    vocab_size = None
    num_steps_sentence = None
    num_steps_story = None
    num_steps_question = None

# %%
class RNN_Model:
    def __init__(self, config):
        self.config = config    
        self.add_placeholders()
        self.inputs_story, self.inputs_question = self.add_embedding()
        self.story_question_state = self.add_basic_model(self.inputs_story, self.inputs_question)

        self.output = self.add_projection(self.story_question_state)

        with tf.name_scope('Accuracy'):
            self.predictions = tf.nn.softmax(self.output)
            self.one_hot_prediction = tf.argmax(self.predictions, 1)
            correct_prediction = tf.equal(tf.argmax(self.labels_placeholder, 1), self.one_hot_prediction)
            self.correct_predictions = tf.reduce_sum(tf.cast(correct_prediction, 'int32'))

        with tf.name_scope('Loss'):
            loss, lossL2 = self.add_loss_op(self.output)
            self.calculate_loss = loss + self.config.L2 * lossL2
        with tf.name_scope('Train'):
            self.train_step = self.add_training_op(self.calculate_loss)

    
    def add_placeholders(self):
        """Generate placeholder variables to represent the input tensors
        """
        self.input_story_placeholder = tf.placeholder(
            tf.int32, shape=[None, self.config.num_steps_story, self.config.num_steps_sentence], name='InputStory')
        self.input_question_placeholder = tf.placeholder(
            tf.int32, shape=[None, self.config.num_steps_question], name='InputQuestion')
        self.labels_placeholder = tf.placeholder(
            tf.int32, shape=[None, self.config.vocab_size], name='Target')
        self.X_length = tf.placeholder(tf.int32, shape=[None], name='X_length')
        self.dropout_placeholder = tf.placeholder(tf.float32, name='Dropout')

        
    def add_embedding(self):
        """Add embedding layer.

        Returns:
          inputs: List of length num_steps, each of whose elements should be
                  a tensor of shape (batch_size, embed_size).
        """
        embedding = tf.get_variable('Embedding', [self.config.vocab_size, self.config.embed_size], trainable=True,
                                    initializer=tf.contrib.layers.xavier_initializer())
        inputs_story = tf.nn.embedding_lookup(embedding, self.input_story_placeholder)
        inputs_question = tf.nn.embedding_lookup(embedding, self.input_question_placeholder)

        # Position Encoding
        inputs_question = tf.expand_dims(inputs_question, 1)
        encoded_story = self.get_position_encoding(inputs_story, self.config.num_steps_sentence, 'StoryEncoding')
        encoded_query = self.get_position_encoding(inputs_question, self.config.num_steps_question, 'QueryEncoding')
        encoded_query = tf.tile(encoded_query, tf.stack([1, self.config.num_steps_story, 1]), name=None)

        return encoded_story, encoded_query

    def get_position_encoding(self, embedding, max_length, scope=None):
        """
        Module described in [End-To-End Memory Networks](https://arxiv.org/abs/1502.01852) as Position Encoding (PE).
        The mask allows the ordering of words in a sentence to affect the encoding.
        """
        J, d = max_length, self.config.embed_size
        l = np.zeros((J, d))
        with tf.variable_scope(scope, 'PE'):
            for j in range(J):
                for k in range(d):
                    l[j, k] = (1. - (j + 1.) / J) - ((k + 1.) / d) * (1. - 2. * (j + 1.) / J)
            self.l = tf.constant(l, shape=[J, d])
            m = tf.reduce_sum(embedding * tf.cast(self.l, tf.float32), 2, name='m')
        return m

    def add_projection(self, rnn_output):
        """Adds a projection layer.

        The projection layer transforms the hidden representation to a distribution
        over the vocabulary.

        Args:
          rnn_output: List of length num_steps, each of whose elements should be
                       a tensor of shape (batch_size, embed_size).
        Returns:
          outputs: List of length num_steps, each a tensor of shape
                   (batch_size, len(vocab))
        """
        with tf.variable_scope('Projection'):
            U = tf.get_variable('Weights',
                                [self.config.hidden_size, self.config.vocab_size], trainable=True,
                                initializer=tf.contrib.layers.xavier_initializer())
            b = tf.get_variable('Bias', [self.config.vocab_size])
            outputs = tf.matmul(rnn_output, U) + b

        return outputs

    def add_loss_op(self, output):
        """Adds loss ops to the computational graph.

        Args:
          output: A tensor of shape (None, self.vocab)
        Returns:
          loss: A 0-d tensor (scalar)
        """
        var = tf.trainable_variables()
        cross_entropy = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(logits=output, labels=self.labels_placeholder))
        tf.add_to_collection('total_loss', cross_entropy)
        loss = tf.add_n(tf.get_collection('total_loss'))
        lossL2 = tf.add_n([tf.nn.l2_loss(v) for v in var if 'Bias' not in v.name])

        return loss, lossL2

    def add_training_op(self, loss):
        """Sets up the training Ops.
        Args:
          loss: Loss tensor, from cross_entropy_loss.
        Returns:
          train_op: The Op for training.
        """
        optimizer = tf.train.AdagradOptimizer(self.config.lr)
        train_op = optimizer.minimize(loss)

        return train_op
    # Baseline model with Basic LSTM Cell and call to dynamic_rnn with concatenated  input and question embeddings   
    def add_basic_model(self, inputs_story, inputs_question):
        basic_lstm = tf.contrib.rnn.BasicLSTMCell(num_units=self.config.hidden_size)
        basic_lstm = tf.contrib.rnn.DropoutWrapper(basic_lstm, input_keep_prob=self.dropout_placeholder,
                                            output_keep_prob=self.dropout_placeholder)

        with tf.variable_scope('basic_cell') as scope:
            a, b = basic_dynamic_rnn(basic_lstm, [inputs_story, inputs_question],
                                            sequence_length=self.X_length,
                                            dtype=tf.float32)

        return tf.reduce_sum(b, 0)
        
    
    def predict(self, session, data):
        input_story, input_question, input_labels, X_length = data
        config = self.config
        dp = 1

        n_data = len(input_story)
        batches = zip(range(0, n_data - config.batch_size, config.batch_size),
                      range(config.batch_size, n_data, config.batch_size))
        batches = [(start, end) for start, end in batches]
        total_correct_examples = 0
        total_processed_examples = 0
        for step, (start, end) in enumerate(batches):
            feed = {self.input_story_placeholder: input_story[start:end],
                    self.input_question_placeholder: input_question[start:end],
                    self.labels_placeholder: input_labels[start:end],
                    self.dropout_placeholder: dp,
                    self.X_length: X_length[start:end]}
            total_correct = session.run(self.correct_predictions, feed_dict=feed)
            total_processed_examples += end - start
            total_correct_examples += total_correct
        acc = total_correct_examples / float(total_processed_examples)

        return acc

    
    def run_epoch(self, session, data, train_op=None, verbose=10):
            input_story, input_question, input_labels, X_length = data
            config = self.config
            dp = config.dropout

            if not train_op:
                train_op = tf.no_op()
                dp = 1

            n_data = len(input_story)
            batches = zip(range(0, n_data - config.batch_size, config.batch_size),
                          range(config.batch_size, n_data, config.batch_size))
            batches = [(start, end) for start, end in batches]
            np.random.shuffle(batches)
            n_val = int(len(batches) * 0.1)
            batches_train = batches[:-n_val]
            batches_val = batches[-n_val:]

            total_loss = []
            total_correct_examples = 0
            total_processed_examples = 0
            total_steps = len(batches_train)
            for step, (start, end) in enumerate(batches_train):
                feed = {self.input_story_placeholder: input_story[start:end],
                        self.input_question_placeholder: input_question[start:end],
                        self.labels_placeholder: input_labels[start:end],
                        self.dropout_placeholder: dp,
                        self.X_length: X_length[start:end]}
                loss, total_correct, _ = session.run(
                    [self.calculate_loss, self.correct_predictions, train_op],
                    feed_dict=feed)
                total_processed_examples += end - start
                total_correct_examples += total_correct
                total_loss.append(loss)
                if verbose and step % verbose == 0:
                    sys.stdout.write('\r{} / {} : loss = {}'.format(
                        step, total_steps, np.mean(total_loss)))
                    sys.stdout.flush()
                if verbose:
                    sys.stdout.write('\r')
            train_acc = total_correct_examples / float(total_processed_examples)

            Story = []
            Question = []
            Answer = []
            Prediction = []
            total_correct_examples = 0
            total_processed_examples = 0
            for step, (start, end) in enumerate(batches_val):
                feed = {self.input_story_placeholder: input_story[start:end],
                        self.input_question_placeholder: input_question[start:end],
                        self.labels_placeholder: input_labels[start:end],
                        self.dropout_placeholder: 1,
                        self.X_length: X_length[start:end]}
                total_correct, prediction = session.run([self.correct_predictions, self.one_hot_prediction], feed_dict=feed)
                total_processed_examples += end - start
                total_correct_examples += total_correct

                Story.append(input_story[start:end])
                Question.append(input_question[start:end])
                Answer.append(input_labels[start:end])
                Prediction.append(prediction)

            val_acc = total_correct_examples / float(total_processed_examples)

            return np.mean(total_loss), train_acc, val_acc, Story, Question, Answer, Prediction

# %%
def basic_dynamic_rnn(cell_fw, inputs, sequence_length=None,
                                     initial_state_fw=None, 
                                     dtype=None, parallel_iterations=None,
                                     swap_memory=False, time_major=False, scope=None):
    with vs.variable_scope(scope or "unidirectional_rnn"):
        
        with vs.variable_scope("fw") as fw_scope:
            inputs_concat = tf.concat(inputs, 1)
            output_fw, output_state_fw = tf.nn.dynamic_rnn(
                cell=cell_fw, inputs=inputs_concat, sequence_length=sequence_length,
                initial_state=initial_state_fw, dtype=dtype
                )
            
    return output_fw, output_state_fw

# %% [markdown]
# ## Data Preprocessing

# %%
def reset_graph(seed=3242):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)


def get_data(task_path):
    #train = get_stories(tar.extractfile(task_path.format('train')), only_supporting=True)
    train = get_stories(tar.extractfile(task_path.format('train')), only_supporting=False)
    #test = get_stories(tar.extractfile(task_path.format('test')), only_supporting=True)
    test = get_stories(tar.extractfile(task_path.format('test')), only_supporting=False)
    return train, test

def get_stories(f, only_supporting=False, max_length=None):
    """Given a file name, read the file, retrieve the stories, and then convert the sentences into a single story.
    If max_length is supplied, any stories longer than max_length tokens will be discarded.
    """
    data = parse_stories(f.readlines(), only_supporting=only_supporting)
    data = [(story, q, answer) for story, q, answer in data if
            not max_length or len(story) < max_length]
    return data
    

def parse_stories(lines, only_supporting=False):
    """
    Parse the bAbI task format.
    If only_supporting is True, only the sentences that support the answer are kept.
    """
    data = []
    story = []
    for line in lines:
        line = line.decode('utf-8').strip()
        nid, line = line.split(' ', 1)
        nid = int(nid)
        if nid == 1:
            story = []
        if '\t' in line:
            q, a, supporting = line.split('\t')
            q = tokenize_word(q)
            if only_supporting:
                # Only select the related substory
                supporting = map(int, supporting.split())
                substory = [story[i - 1] for i in supporting]
            else:
                # Provide all the substories
                substory = [x for x in story if x]
            data.append((substory, q, a))
            story.append('')
        else:
            sent = tokenize_word(line)
            story.append(sent)
    return data


def tokenize_word(sent):
    """Return the tokens of a sentence excluding punctuation.
    >> tokenize('Bob dropped the apple. Where is the apple?')
    ['Bob', 'dropped', 'the', 'apple', 'Bob', 'went', 'to', 'the', 'kitchen']
    """
    return [x.strip() for x in re.split('(\W+)?', sent) if x.strip()]


def vectorize_stories(data, word_idx, sentence_maxlen, story_maxlen, query_maxlen):
    X = []
    Xq = []
    Y = []
    X_length = []

    for story, query, answer in data:
        sentences = []
        for s in story:
            sentence = [word_idx[w] for w in s]
            for _ in range(sentence_maxlen - len(sentence)):
                sentence.append(0)
            assert len(sentence) == sentence_maxlen
            sentences.append(sentence)
        X_length.append(len(sentences))

        ## story
        for _ in range(story_maxlen - len(sentences)):
            sentences.append([0 for _ in range(sentence_maxlen)])

        ## query
        xq = [word_idx[w] for w in query]
        for _ in range(query_maxlen - len(xq)):
            xq.append(0)
        ## answer
        y = np.zeros(len(word_idx) + 1)  # index 0 is reserved
        y[word_idx[answer]] = 1

        X.append(sentences)
        Xq.append(xq)
        Y.append(y)

    return X, Xq, np.array(Y), X_length

# %%
reset_graph()
tasks = [
    'qa1_single-supporting-fact', 'qa2_two-supporting-facts', 'qa3_three-supporting-facts',
    'qa4_two-arg-relations', 'qa5_three-arg-relations', 'qa6_yes-no-questions', 'qa7_counting',
    'qa8_lists-sets', 'qa9_simple-negation', 'qa10_indefinite-knowledge',
    'qa11_basic-coreference', 'qa12_conjunction', 'qa13_compound-coreference',
    'qa14_time-reasoning', 'qa15_basic-deduction', 'qa16_basic-induction', 'qa17_positional-reasoning',
    'qa18_size-reasoning', 'qa19_path-finding', 'qa20_agents-motivations'
]


verbose = True
path = 'babi/babi_tasks_data_1_20_v1.2.tar.gz'
tar = tarfile.open(path)
tasks_dir = 'tasks_1-20_v1-2/en/'
#tasks_dir = 'tasks_1-20_v1-2/en-10k/'


for task in tasks:
    print('\n**************************************\n')
    print(task)
    
    task_path = tasks_dir + task + '_{}.txt'
    
    train, test = get_data(task_path)

    
    flatten = lambda data: [i for i in chain(*data)]
    vocab = sorted(reduce(lambda x, y: x | y, (set(flatten(story) + q + [answer])
                                               for story, q, answer in train + test)))

    # 0 is reserved for masking via pad_sequences
    vocab_size = len(vocab) + 1
    word_idx = dict((c, i + 1) for i, c in enumerate(vocab))

    sentence_maxlen = max(flatten([[len(s) for s in x] for x, _, _ in train + test]))
    #sentence_maxlen = max([i for i in chain(*[[len(s) for s in x] for x, _, _ in train + test])])
    story_maxlen = max(map(len, (x for x, _, _ in train + test)))
    query_maxlen = max(map(len, (x for _, x, _ in train + test)))
    
    idx_word = {v: k for k, v in word_idx.iteritems()}
    idx_word[0] = "_PAD"
     
    X, Xq, Y, X_length = vectorize_stories(train, word_idx, sentence_maxlen, story_maxlen, query_maxlen)
    tX, tXq, tY, tX_length = vectorize_stories(test, word_idx, sentence_maxlen, story_maxlen, query_maxlen)
    
    if verbose:
        print('vocab = {}'.format(vocab))
        print('word_idx = {}'.format(word_idx))
        print('X.shape = {}'.format(np.array(X).shape))
        print('Xq.shape = {}'.format(np.array(Xq).shape))
        print('Y.shape = {}'.format(Y.shape))
        print('story_maxlen, sentence_maxlen, query_maxlen = {}, {}, {}'.format(story_maxlen, sentence_maxlen, query_maxlen))

    config = Config()
    config.vocab_size = vocab_size
    config.num_steps_sentence = sentence_maxlen
    config.num_steps_story = story_maxlen
    config.num_steps_question = query_maxlen
    print('max_epochs = {}'.format(config.max_epochs)) 
    with tf.Graph().as_default() as g:
        model = RNN_Model(config)
        init = tf.global_variables_initializer()

        with tf.Session() as session:
            session.run(init)

            for epoch in range(config.max_epochs):
                print('Epoch {}'.format(epoch))

                train_loss, train_acc, val_acc, Story, Question, Answer, Prediction = model.run_epoch(session, (
                    X, Xq, Y, X_length), train_op=model.train_step)

                if verbose:
                    print('Training loss: {}'.format(train_loss))
                    print('Training acc: {}'.format(train_acc))
                    print('Validation acc: {}'.format(val_acc))


                if epoch % 10 == 0:
                    test_acc = model.predict(session, (tX, tXq, tY, tX_length))
                    print('Testing acc: {}'.format(test_acc))
# Out:
# **************************************
#
# qa1_single-supporting-fact
# vocab = [u'.', u'?', u'Daniel', u'John', u'Mary', u'Sandra', u'Where', u'back', u'bathroom', u'bedroom', u'garden', u'hallway', u'is', u'journeyed', u'kitchen', u'moved', u'office', u'the', u'to', u'travelled', u'went']
# word_idx = {u'hallway': 12, u'bathroom': 9, u'garden': 11, u'journeyed': 14, u'office': 17, u'is': 13, u'bedroom': 10, u'moved': 16, u'back': 8, u'went': 21, u'.': 1, u'to': 19, u'travelled': 20, u'Daniel': 3, u'Sandra': 6, u'the': 18, u'John': 4, u'Where': 7, u'Mary': 5, u'?': 2, u'kitchen': 15}
# X.shape = (1000, 10, 7)
# Xq.shape = (1000, 4)
# Y.shape = (1000, 22)
# story_maxlen, sentence_maxlen, query_maxlen = 10, 7, 4
# max_epochs = 501
# Couldn't import dot_parser, loading of dot files will not be possible.
# Epoch 0
# Training loss: 2.5520761013
# Training acc: 0.162946428571
# Validation acc: 0.260416666667
# Testing acc: 0.232862903226
# Epoch 1
# Training loss: 2.05978631973
# Training acc: 0.207589285714
# Validation acc: 0.239583333333
# Epoch 2
# Training loss: 1.94867122173
# Training acc: 0.264508928571
# Validation acc: 0.291666666667
# Epoch 3
# Training loss: 1.88983845711
# Training acc: 0.305803571429
# Validation acc: 0.260416666667
# Epoch 4
# Training loss: 1.84750401974
# Training acc: 0.334821428571
# Validation acc: 0.375
# Epoch 5
# Training loss: 1.8215572834
# Training acc: 0.354910714286
# Validation acc: 0.364583333333
# Epoch 6
# Training loss: 1.79745447636
# Training acc: 0.376116071429
# Validation acc: 0.4375
# Epoch 7
# Training loss: 1.77422809601
# Training acc: 0.409598214286
# Validation acc: 0.510416666667
# Epoch 8
# Training loss: 1.74559092522
# Training acc: 0.430803571429
# Validation acc: 0.4375
# Epoch 9
# Training loss: 1.71953332424
# Training acc: 0.4296875
# Validation acc: 0.427083333333
# Epoch 10
# Training loss: 1.68987154961
# Training acc: 0.452008928571
# Validation acc: 0.489583333333
# Testing acc: 0.430443548387
# Epoch 11
# Training loss: 1.6734200716
# Training acc: 0.469866071429
# Validation acc: 0.479166666667
# Epoch 12
# Training loss: 1.65528130531
# Training acc: 0.465401785714
# Validation acc: 0.552083333333
# Epoch 13
# Training loss: 1.61899447441
# Training acc: 0.493303571429
# Validation acc: 0.46875
# Epoch 14
# Training loss: 1.59196949005
# Training acc: 0.485491071429
# Validation acc: 0.510416666667
# Epoch 15
# Training loss: 1.56722164154
# Training acc: 0.5
# Validation acc: 0.604166666667
# Epoch 16
# Training loss: 1.54199063778
# Training acc: 0.520089285714
# Validation acc: 0.541666666667
# Epoch 17
# Training loss: 1.51466953754
# Training acc: 0.517857142857
# Validation acc: 0.46875
# Epoch 18
# Training loss: 1.5083091259
# Training acc: 0.502232142857
# Validation acc: 0.604166666667
# Epoch 19
# Training loss: 1.48218798637
# Training acc: 0.5234375
# Validation acc: 0.5
# Epoch 20
# Training loss: 1.4409481287
# Training acc: 0.527901785714
# Validation acc: 0.46875
# Testing acc: 0.479838709677
# Epoch 21
# Training loss: 1.43582344055
# Training acc: 0.527901785714
# Validation acc: 0.552083333333
# Epoch 22
# Training loss: 1.40516412258
# Training acc: 0.524553571429
# Validation acc: 0.479166666667
# Epoch 23
# Training loss: 1.39634954929
# Training acc: 0.543526785714
# Validation acc: 0.53125
# Epoch 24
# Training loss: 1.37987029552
# Training acc: 0.542410714286
# Validation acc: 0.53125
# Epoch 25
# Training loss: 1.36764407158
# Training acc: 0.53125
# Validation acc: 0.59375
# Epoch 26
# Training loss: 1.34566009045
# Training acc: 0.537946428571
# Validation acc: 0.583333333333
# Epoch 27
# Training loss: 1.33146309853
# Training acc: 0.522321428571
# Validation acc: 0.614583333333
# Epoch 28
# Training loss: 1.31411147118
# Training acc: 0.559151785714
# Validation acc: 0.479166666667
# Epoch 29
# Training loss: 1.29871428013
# Training acc: 0.560267857143
# Validation acc: 0.541666666667
# Epoch 30
# Training loss: 1.28710401058
# Training acc: 0.558035714286
# Validation acc: 0.572916666667
# Testing acc: 0.497983870968
# Epoch 31
# Training loss: 1.2909040451
# Training acc: 0.534598214286
# Validation acc: 0.635416666667
# Epoch 32
# Training loss: 1.29713177681
# Training acc: 0.540178571429
# Validation acc: 0.552083333333
# Epoch 33
# Training loss: 1.26338636875
# Training acc: 0.566964285714
# Validation acc: 0.541666666667
# Epoch 34
# Training loss: 1.27224600315
# Training acc: 0.555803571429
# Validation acc: 0.65625
# Epoch 35
# Training loss: 1.25609505177
# Training acc: 0.550223214286
# Validation acc: 0.5625
# Epoch 36
# Training loss: 1.27897202969
# Training acc: 0.542410714286
# Validation acc: 0.666666666667
# Epoch 37
# Training loss: 1.25562536716
# Training acc: 0.550223214286
# Validation acc: 0.510416666667
# Epoch 38
# Training loss: 1.23089528084
# Training acc: 0.572544642857
# Validation acc: 0.5625
# Epoch 39
# Training loss: 1.2150169611
# Training acc: 0.579241071429
# Validation acc: 0.583333333333
# Epoch 40
# Training loss: 1.22524166107
# Training acc: 0.553571428571
# Validation acc: 0.510416666667
# Testing acc: 0.491935483871
# Epoch 41
# Training loss: 1.21423017979
# Training acc: 0.561383928571
# Validation acc: 0.572916666667
# Epoch 42
# Training loss: 1.2339193821
# Training acc: 0.566964285714
# Validation acc: 0.635416666667
# Epoch 43
# Training loss: 1.19620072842
# Training acc: 0.571428571429
# Validation acc: 0.520833333333
# Epoch 44
# Training loss: 1.20892715454
# Training acc: 0.575892857143
# Validation acc: 0.520833333333
# Epoch 45
# Training loss: 1.18524610996
# Training acc: 0.589285714286
# Validation acc: 0.5625
# Epoch 46
# Training loss: 1.19960463047
# Training acc: 0.563616071429
# Validation acc: 0.552083333333
# Epoch 47
# Training loss: 1.19641304016
# Training acc: 0.580357142857
# Validation acc: 0.53125
# Epoch 48
# Training loss: 1.19431459904
# Training acc: 0.5859375
# Validation acc: 0.5625
# Epoch 49
# Training loss: 1.19634282589
# Training acc: 0.563616071429
# Validation acc: 0.53125
# Epoch 50
# Training loss: 1.1955820322
# Training acc: 0.5703125
# Validation acc: 0.635416666667
# Testing acc: 0.505040322581
# Epoch 51
# Training loss: 1.18502831459
# Training acc: 0.588169642857
# Validation acc: 0.53125
# Epoch 52
# Training loss: 1.16856026649
# Training acc: 0.590401785714
# Validation acc: 0.572916666667
# Epoch 53
# Training loss: 1.19752657413
# Training acc: 0.568080357143
# Validation acc: 0.604166666667
# Epoch 54
# Training loss: 1.17619287968
# Training acc: 0.575892857143
# Validation acc: 0.552083333333
# Epoch 55
# Training loss: 1.18693947792
# Training acc: 0.578125
# Validation acc: 0.59375
# Epoch 56
# Training loss: 1.18633806705
# Training acc: 0.583705357143
# Validation acc: 0.583333333333
# Epoch 57
# Training loss: 1.17729449272
# Training acc: 0.582589285714
# Validation acc: 0.5625
# Epoch 58
# Training loss: 1.17111766338
# Training acc: 0.582589285714
# Validation acc: 0.552083333333
# Epoch 59
# Training loss: 1.19240391254
# Training acc: 0.573660714286
# Validation acc: 0.65625
# Epoch 60
# Training loss: 1.16236782074
# Training acc: 0.584821428571
# Validation acc: 0.5625
# Testing acc: 0.505040322581
# Epoch 61
# Training loss: 1.17130112648
# Training acc: 0.572544642857
# Validation acc: 0.583333333333
# Epoch 62
# Training loss: 1.16199469566
# Training acc: 0.580357142857
# Validation acc: 0.520833333333
# Epoch 63
# Training loss: 1.18448543549
# Training acc: 0.574776785714
# Validation acc: 0.614583333333
# Epoch 64
# Training loss: 1.15683853626
# Training acc: 0.582589285714
# Validation acc: 0.541666666667
# Epoch 65
# Training loss: 1.16897761822
# Training acc: 0.574776785714
# Validation acc: 0.572916666667
# Epoch 66
# Training loss: 1.13568556309
# Training acc: 0.598214285714
# Validation acc: 0.5
# Epoch 67
# Training loss: 1.14345443249
# Training acc: 0.580357142857
# Validation acc: 0.572916666667
# Epoch 68
# Training loss: 1.16539859772
# Training acc: 0.580357142857
# Validation acc: 0.583333333333
# Epoch 69
# Training loss: 1.1451280117
# Training acc: 0.594866071429
# Validation acc: 0.552083333333
# Epoch 70
# Training loss: 1.17201542854
# Training acc: 0.589285714286
# Validation acc: 0.59375
# Testing acc: 0.51310483871
# Epoch 71
# Training loss: 1.1627022028
# Training acc: 0.589285714286
# Validation acc: 0.625
# Epoch 72
# Training loss: 1.14563858509
# Training acc: 0.591517857143
# Validation acc: 0.604166666667
# Epoch 73
# Training loss: 1.13118779659
# Training acc: 0.579241071429
# Validation acc: 0.552083333333
# Epoch 74
# Training loss: 1.15041363239
# Training acc: 0.587053571429
# Validation acc: 0.625
# Epoch 75
# Training loss: 1.16287636757
# Training acc: 0.581473214286
# Validation acc: 0.5625
# Epoch 76
# Training loss: 1.15690970421
# Training acc: 0.581473214286
# Validation acc: 0.5625
# Epoch 77
# Training loss: 1.15915668011
# Training acc: 0.583705357143
# Validation acc: 0.583333333333
# Epoch 78
# Training loss: 1.16079592705
# Training acc: 0.574776785714
# Validation acc: 0.604166666667
# Epoch 79
# Training loss: 1.15624892712
# Training acc: 0.595982142857
# Validation acc: 0.604166666667
# Epoch 80
# Training loss: 1.15290093422
# Training acc: 0.581473214286
# Validation acc: 0.614583333333
# Testing acc: 0.504032258065
# Epoch 81
# Training loss: 1.12955546379
# Training acc: 0.582589285714
# Validation acc: 0.614583333333
# Epoch 82
# Training loss: 1.12983441353
# Training acc: 0.59375
# Validation acc: 0.572916666667
# Epoch 83
# Training loss: 1.15449225903
# Training acc: 0.587053571429
# Validation acc: 0.625
# Epoch 84
# Training loss: 1.1572227478
# Training acc: 0.584821428571
# Validation acc: 0.625
# Epoch 85
# Training loss: 1.1468116045
# Training acc: 0.584821428571
# Validation acc: 0.604166666667
# Epoch 86
# Training loss: 1.14846026897
# Training acc: 0.582589285714
# Validation acc: 0.59375
# Epoch 87
# Training loss: 1.13719010353
# Training acc: 0.581473214286
# Validation acc: 0.572916666667
# Epoch 88
# Training loss: 1.14325535297
# Training acc: 0.6015625
# Validation acc: 0.572916666667
# Epoch 89
# Training loss: 1.15984916687
# Training acc: 0.575892857143
# Validation acc: 0.635416666667
# Epoch 90
# Training loss: 1.13472414017
# Training acc: 0.583705357143
# Validation acc: 0.583333333333
# Testing acc: 0.509072580645
# Epoch 91
# Training loss: 1.14902615547
# Training acc: 0.574776785714
# Validation acc: 0.604166666667
# Epoch 92
# Training loss: 1.15609037876
# Training acc: 0.580357142857
# Validation acc: 0.604166666667
# Epoch 93
# Training loss: 1.12529015541
# Training acc: 0.595982142857
# Validation acc: 0.520833333333
# Epoch 94
# Training loss: 1.12854540348
# Training acc: 0.603794642857
# Validation acc: 0.572916666667
# Epoch 95
# Training loss: 1.14714646339
# Training acc: 0.575892857143
# Validation acc: 0.583333333333
# Epoch 96
# Training loss: 1.14729106426
# Training acc: 0.598214285714
# Validation acc: 0.614583333333
# Epoch 97
# Training loss: 1.13235974312
# Training acc: 0.594866071429
# Validation acc: 0.583333333333
# Epoch 98
# Training loss: 1.14124691486
# Training acc: 0.582589285714
# Validation acc: 0.635416666667
# Epoch 99
# Training loss: 1.14066493511
# Training acc: 0.577008928571
# Validation acc: 0.520833333333
# Epoch 100
# Training loss: 1.13888692856
# Training acc: 0.578125
# Validation acc: 0.583333333333
# Testing acc: 0.511088709677
# Epoch 101
# Training loss: 1.12209522724
# Training acc: 0.594866071429
# Validation acc: 0.635416666667
# Epoch 102
# Training loss: 1.15195536613
# Training acc: 0.583705357143
# Validation acc: 0.614583333333
# Epoch 103
# Training loss: 1.12772119045
# Training acc: 0.599330357143
# Validation acc: 0.541666666667
# Epoch 104
# Training loss: 1.13082897663
# Training acc: 0.589285714286
# Validation acc: 0.479166666667
# Epoch 105
# Training loss: 1.14914572239
# Training acc: 0.563616071429
# Validation acc: 0.6875
# Epoch 106
# Training loss: 1.13039803505
# Training acc: 0.590401785714
# Validation acc: 0.552083333333
# Epoch 107
# Training loss: 1.14988827705
# Training acc: 0.5859375
# Validation acc: 0.625
# Epoch 108
# Training loss: 1.1570776701
# Training acc: 0.590401785714
# Validation acc: 0.65625
# Epoch 109
# Training loss: 1.1224052906
# Training acc: 0.597098214286
# Validation acc: 0.59375
# Epoch 110
# Training loss: 1.1452524662
# Training acc: 0.591517857143
# Validation acc: 0.625
# Testing acc: 0.512096774194
# Epoch 111
# Training loss: 1.15066027641
# Training acc: 0.580357142857
# Validation acc: 0.677083333333
# Epoch 112
# Training loss: 1.15516746044
# Training acc: 0.572544642857
# Validation acc: 0.697916666667
# Epoch 113
# Training loss: 1.1603564024
# Training acc: 0.583705357143
# Validation acc: 0.697916666667
# Epoch 114
# Training loss: 1.13072347641
# Training acc: 0.587053571429
# Validation acc: 0.5625
# Epoch 115
# Training loss: 1.12409043312
# Training acc: 0.589285714286
# Validation acc: 0.614583333333
# Epoch 116
# Training loss: 1.13335716724
# Training acc: 0.588169642857
# Validation acc: 0.583333333333
# Epoch 117
# Training loss: 1.13481736183
# Training acc: 0.59375
# Validation acc: 0.5625
# Epoch 118
# Training loss: 1.10644972324
# Training acc: 0.599330357143
# Validation acc: 0.604166666667
# Epoch 119
# Training loss: 1.12741935253
# Training acc: 0.606026785714
# Validation acc: 0.59375
# Epoch 120
# Training loss: 1.14416253567
# Training acc: 0.589285714286
# Validation acc: 0.645833333333
# Testing acc: 0.502016129032
# Epoch 121
# Training loss: 1.12042152882
# Training acc: 0.607142857143
# Validation acc: 0.552083333333
# Epoch 122
# Training loss: 1.12502419949
# Training acc: 0.598214285714
# Validation acc: 0.614583333333
# Epoch 123
# Training loss: 1.12179994583
# Training acc: 0.5859375
# Validation acc: 0.677083333333
# Epoch 124
# Training loss: 1.11834454536
# Training acc: 0.610491071429
# Validation acc: 0.541666666667
# Epoch 125
# Training loss: 1.11422848701
# Training acc: 0.594866071429
# Validation acc: 0.604166666667
# Epoch 126
# Training loss: 1.12333333492
# Training acc: 0.594866071429
# Validation acc: 0.625
# Epoch 127
# Training loss: 1.10218751431
# Training acc: 0.595982142857
# Validation acc: 0.541666666667
# Epoch 128
# Training loss: 1.1454603672
# Training acc: 0.580357142857
# Validation acc: 0.6875
# Epoch 129
# Training loss: 1.12545502186
# Training acc: 0.588169642857
# Validation acc: 0.604166666667
# Epoch 130
# Training loss: 1.13259875774
# Training acc: 0.579241071429
# Validation acc: 0.552083333333
# Testing acc: 0.505040322581
# Epoch 131
# Training loss: 1.1271790266
# Training acc: 0.59375
# Validation acc: 0.552083333333
# Epoch 132
# Training loss: 1.11413168907
# Training acc: 0.6015625
# Validation acc: 0.572916666667
# Epoch 133
# Training loss: 1.15234696865
# Training acc: 0.575892857143
# Validation acc: 0.71875
# Epoch 134
# Training loss: 1.13816738129
# Training acc: 0.584821428571
# Validation acc: 0.625
# Epoch 135
# Training loss: 1.11700427532
# Training acc: 0.606026785714
# Validation acc: 0.552083333333
# Epoch 136
# Training loss: 1.12686741352
# Training acc: 0.580357142857
# Validation acc: 0.583333333333
# Epoch 137
# Training loss: 1.10984790325
# Training acc: 0.594866071429
# Validation acc: 0.583333333333
# Epoch 138
# Training loss: 1.11924219131
# Training acc: 0.604910714286
# Validation acc: 0.614583333333
# Epoch 139
# Training loss: 1.11908888817
# Training acc: 0.590401785714
# Validation acc: 0.625
# Epoch 140
# Training loss: 1.09068584442
# Training acc: 0.608258928571
# Validation acc: 0.5625
# Testing acc: 0.504032258065
# Epoch 141
# Training loss: 1.12907671928
# Training acc: 0.580357142857
# Validation acc: 0.635416666667
# Epoch 142
# Training loss: 1.1113089323
# Training acc: 0.6015625
# Validation acc: 0.552083333333
# Epoch 143
# Training loss: 1.1000212431
# Training acc: 0.604910714286
# Validation acc: 0.583333333333
# Epoch 144
# Training loss: 1.10900425911
# Training acc: 0.59375
# Validation acc: 0.614583333333
# Epoch 145
# Training loss: 1.09305083752
# Training acc: 0.594866071429
# Validation acc: 0.552083333333
# Epoch 146
# Training loss: 1.11922395229
# Training acc: 0.602678571429
# Validation acc: 0.635416666667
# Epoch 147
# Training loss: 1.1176213026
# Training acc: 0.587053571429
# Validation acc: 0.5625
# Epoch 148
# Training loss: 1.10968363285
# Training acc: 0.590401785714
# Validation acc: 0.604166666667
# Epoch 149
# Training loss: 1.11001932621
# Training acc: 0.592633928571
# Validation acc: 0.625
# Epoch 150
# Training loss: 1.09712541103
# Training acc: 0.603794642857
# Validation acc: 0.552083333333
# Testing acc: 0.504032258065
# Epoch 151
# Training loss: 1.11347353458
# Training acc: 0.583705357143
# Validation acc: 0.635416666667
# Epoch 152
# Training loss: 1.10131549835
# Training acc: 0.602678571429
# Validation acc: 0.604166666667
# Epoch 153
# Training loss: 1.12343418598
# Training acc: 0.5859375
# Validation acc: 0.625
# Epoch 154
# Training loss: 1.11032474041
# Training acc: 0.587053571429
# Validation acc: 0.614583333333
# Epoch 155
# Training loss: 1.12134957314
# Training acc: 0.603794642857
# Validation acc: 0.604166666667
# Epoch 156
# Training loss: 1.10996103287
# Training acc: 0.595982142857
# Validation acc: 0.625
# Epoch 157
# Training loss: 1.11203503609
# Training acc: 0.587053571429
# Validation acc: 0.583333333333
# Epoch 158
# Training loss: 1.12191021442
# Training acc: 0.580357142857
# Validation acc: 0.65625
# Epoch 159
# Training loss: 1.1326264143
# Training acc: 0.602678571429
# Validation acc: 0.677083333333
# Epoch 160
# Training loss: 1.11474537849
# Training acc: 0.588169642857
# Validation acc: 0.604166666667
# Testing acc: 0.508064516129
# Epoch 161
# Training loss: 1.09139788151
# Training acc: 0.606026785714
# Validation acc: 0.5625
# Epoch 162
# Training loss: 1.10874831676
# Training acc: 0.604910714286
# Validation acc: 0.583333333333
# Epoch 163
# Training loss: 1.11242747307
# Training acc: 0.582589285714
# Validation acc: 0.645833333333
# Epoch 164
# Training loss: 1.11268532276
# Training acc: 0.584821428571
# Validation acc: 0.5625
# Epoch 165
# Training loss: 1.09480392933
# Training acc: 0.592633928571
# Validation acc: 0.604166666667
# Epoch 166
# Training loss: 1.09289956093
# Training acc: 0.598214285714
# Validation acc: 0.5625
# Epoch 167
# Training loss: 1.10265505314
# Training acc: 0.604910714286
# Validation acc: 0.5625
# Epoch 168
# Training loss: 1.09598112106
# Training acc: 0.59375
# Validation acc: 0.583333333333
# Epoch 169
# Training loss: 1.11676239967
# Training acc: 0.600446428571
# Validation acc: 0.635416666667
# Epoch 170
# Training loss: 1.09515488148
# Training acc: 0.607142857143
# Validation acc: 0.614583333333
# Testing acc: 0.506048387097
# Epoch 171
# Training loss: 1.08796811104
# Training acc: 0.607142857143
# Validation acc: 0.614583333333
# Epoch 172
# Training loss: 1.11875414848
# Training acc: 0.5859375
# Validation acc: 0.65625
# Epoch 173
# Training loss: 1.11025738716
# Training acc: 0.5859375
# Validation acc: 0.604166666667
# Epoch 174
# Training loss: 1.08765411377
# Training acc: 0.599330357143
# Validation acc: 0.572916666667
# Epoch 175
# Training loss: 1.11255908012
# Training acc: 0.594866071429
# Validation acc: 0.6875
# Epoch 176
# Training loss: 1.0896178484
# Training acc: 0.599330357143
# Validation acc: 0.583333333333
# Epoch 177
# Training loss: 1.09782922268
# Training acc: 0.599330357143
# Validation acc: 0.604166666667
# Epoch 178
# Training loss: 1.10678601265
# Training acc: 0.591517857143
# Validation acc: 0.604166666667
# Epoch 179
# Training loss: 1.06559240818
# Training acc: 0.608258928571
# Validation acc: 0.5625
# Epoch 180
# Training loss: 1.09058368206
# Training acc: 0.606026785714
# Validation acc: 0.614583333333
# Testing acc: 0.508064516129
# Epoch 181
# Training loss: 1.0920689106
# Training acc: 0.610491071429
# Validation acc: 0.645833333333
# Epoch 182
# Training loss: 1.09838604927
# Training acc: 0.591517857143
# Validation acc: 0.625
# Epoch 183
# Training loss: 1.09481346607
# Training acc: 0.6015625
# Validation acc: 0.583333333333
# Epoch 184
# Training loss: 1.08296048641
# Training acc: 0.59375
# Validation acc: 0.625
# Epoch 185
# Training loss: 1.10731720924
# Training acc: 0.594866071429
# Validation acc: 0.625
# Epoch 186
# Training loss: 1.07279670238
# Training acc: 0.609375
# Validation acc: 0.5
# Epoch 187
# Training loss: 1.08711731434
# Training acc: 0.59375
# Validation acc: 0.625
# Epoch 188
# Training loss: 1.08088850975
# Training acc: 0.612723214286
# Validation acc: 0.625
# Epoch 189
# Training loss: 1.10480690002
# Training acc: 0.588169642857
# Validation acc: 0.625
# Epoch 190
# Training loss: 1.09440863132
# Training acc: 0.59375
# Validation acc: 0.625
# Testing acc: 0.507056451613
# Epoch 191
# Training loss: 1.10206031799
# Training acc: 0.5859375
# Validation acc: 0.645833333333
# Epoch 192
# Training loss: 1.09930098057
# Training acc: 0.602678571429
# Validation acc: 0.59375
# Epoch 193
# Training loss: 1.11368441582
# Training acc: 0.592633928571
# Validation acc: 0.666666666667
# Epoch 194
# Training loss: 1.10731625557
# Training acc: 0.588169642857
# Validation acc: 0.583333333333
# Epoch 195
# Training loss: 1.10245072842
# Training acc: 0.6015625
# Validation acc: 0.625
# Epoch 196
# Training loss: 1.09832751751
# Training acc: 0.602678571429
# Validation acc: 0.6875
# Epoch 197
# Training loss: 1.11880671978
# Training acc: 0.587053571429
# Validation acc: 0.645833333333
# Epoch 198
# Training loss: 1.086810112
# Training acc: 0.619419642857
# Validation acc: 0.5625
# Epoch 199
# Training loss: 1.10446858406
# Training acc: 0.594866071429
# Validation acc: 0.604166666667
# Epoch 200
# Training loss: 1.11323666573
# Training acc: 0.592633928571
# Validation acc: 0.645833333333
# Testing acc: 0.511088709677
# Epoch 201
# Training loss: 1.08988702297
# Training acc: 0.603794642857
# Validation acc: 0.604166666667
# Epoch 202
# Training loss: 1.08453047276
# Training acc: 0.595982142857
# Validation acc: 0.635416666667
# Epoch 203
# Training loss: 1.09804189205
# Training acc: 0.595982142857
# Validation acc: 0.604166666667
# Epoch 204
# Training loss: 1.10115242004
# Training acc: 0.602678571429
# Validation acc: 0.697916666667
# Epoch 205
# Training loss: 1.07543087006
# Training acc: 0.609375
# Validation acc: 0.572916666667
# Epoch 206
# Training loss: 1.06260180473
# Training acc: 0.598214285714
# Validation acc: 0.604166666667
# Epoch 207
# Training loss: 1.067938447
# Training acc: 0.614955357143
# Validation acc: 0.614583333333
# Epoch 208
# Training loss: 1.09906637669
# Training acc: 0.590401785714
# Validation acc: 0.6875
# Epoch 209
# Training loss: 1.07705461979
# Training acc: 0.603794642857
# Validation acc: 0.645833333333
# Epoch 210
# Training loss: 1.07852482796
# Training acc: 0.614955357143
# Validation acc: 0.572916666667
# Testing acc: 0.506048387097
# Epoch 211
# Training loss: 1.07711541653
# Training acc: 0.6015625
# Validation acc: 0.625
# Epoch 212
# Training loss: 1.08814120293
# Training acc: 0.607142857143
# Validation acc: 0.541666666667
# Epoch 213
# Training loss: 1.09722030163
# Training acc: 0.598214285714
# Validation acc: 0.625
# Epoch 214
# Training loss: 1.09091842175
# Training acc: 0.609375
# Validation acc: 0.635416666667
# Epoch 215
# Training loss: 1.08510649204
# Training acc: 0.592633928571
# Validation acc: 0.59375
# Epoch 216
# Training loss: 1.07064914703
# Training acc: 0.607142857143
# Validation acc: 0.614583333333
# Epoch 217
# Training loss: 1.09154593945
# Training acc: 0.604910714286
# Validation acc: 0.625
# Epoch 218
# Training loss: 1.07571351528
# Training acc: 0.599330357143
# Validation acc: 0.604166666667
# Epoch 219
# Training loss: 1.0756957531
# Training acc: 0.608258928571
# Validation acc: 0.572916666667
# Epoch 220
# Training loss: 1.06761586666
# Training acc: 0.599330357143
# Validation acc: 0.614583333333
# Testing acc: 0.509072580645
# Epoch 221
# Training loss: 1.07402479649
# Training acc: 0.600446428571
# Validation acc: 0.614583333333
# Epoch 222
# Training loss: 1.08747565746
# Training acc: 0.598214285714
# Validation acc: 0.572916666667
# Epoch 223
# Training loss: 1.08077168465
# Training acc: 0.602678571429
# Validation acc: 0.583333333333
# Epoch 224
# Training loss: 1.08606851101
# Training acc: 0.583705357143
# Validation acc: 0.6875
# Epoch 225
# Training loss: 1.08395206928
# Training acc: 0.606026785714
# Validation acc: 0.635416666667
# Epoch 226
# Training loss: 1.11851608753
# Training acc: 0.583705357143
# Validation acc: 0.645833333333
# Epoch 227
# Training loss: 1.07124233246
# Training acc: 0.609375
# Validation acc: 0.59375
# Epoch 228
# Training loss: 1.06503522396
# Training acc: 0.622767857143
# Validation acc: 0.604166666667
# Epoch 229
# Training loss: 1.07996189594
# Training acc: 0.602678571429
# Validation acc: 0.5625
# Epoch 230
# Training loss: 1.08376097679
# Training acc: 0.589285714286
# Validation acc: 0.625
# Testing acc: 0.512096774194
# Epoch 231
# Training loss: 1.06592869759
# Training acc: 0.6171875
# Validation acc: 0.677083333333
# Epoch 232
# Training loss: 1.08573400974
# Training acc: 0.614955357143
# Validation acc: 0.635416666667
# Epoch 233
# Training loss: 1.07609915733
# Training acc: 0.604910714286
# Validation acc: 0.645833333333
# Epoch 234
# Training loss: 1.07223367691
# Training acc: 0.622767857143
# Validation acc: 0.604166666667
# Epoch 235
# Training loss: 1.08078324795
# Training acc: 0.602678571429
# Validation acc: 0.708333333333
# Epoch 236
# Training loss: 1.0582703352
# Training acc: 0.604910714286
# Validation acc: 0.635416666667
# Epoch 237
# Training loss: 1.05266022682
# Training acc: 0.611607142857
# Validation acc: 0.583333333333
# Epoch 238
# Training loss: 1.07536578178
# Training acc: 0.582589285714
# Validation acc: 0.59375
# Epoch 239
# Training loss: 1.0834249258
# Training acc: 0.600446428571
# Validation acc: 0.625
# Epoch 240
# Training loss: 1.10034644604
# Training acc: 0.597098214286
# Validation acc: 0.614583333333
# Testing acc: 0.512096774194
# Epoch 241
# Training loss: 1.08320200443
# Training acc: 0.603794642857
# Validation acc: 0.614583333333
# Epoch 242
# Training loss: 1.07300102711
# Training acc: 0.6015625
# Validation acc: 0.625
# Epoch 243
# Training loss: 1.06924843788
# Training acc: 0.603794642857
# Validation acc: 0.604166666667
# Epoch 244
# Training loss: 1.07820928097
# Training acc: 0.613839285714
# Validation acc: 0.614583333333
# Epoch 245
# Training loss: 1.07450675964
# Training acc: 0.602678571429
# Validation acc: 0.604166666667
# Epoch 246
# Training loss: 1.05004441738
# Training acc: 0.616071428571
# Validation acc: 0.583333333333
# Epoch 247
# Training loss: 1.06391990185
# Training acc: 0.618303571429
# Validation acc: 0.5625
# Epoch 248
# Training loss: 1.08324217796
# Training acc: 0.588169642857
# Validation acc: 0.6875
# Epoch 249
# Training loss: 1.07696032524
# Training acc: 0.592633928571
# Validation acc: 0.65625
# Epoch 250
# Training loss: 1.07861971855
# Training acc: 0.588169642857
# Validation acc: 0.677083333333
# Testing acc: 0.512096774194
# Epoch 251
# Training loss: 1.07233154774
# Training acc: 0.607142857143
# Validation acc: 0.59375
# Epoch 252
# Training loss: 1.07784235477
# Training acc: 0.600446428571
# Validation acc: 0.697916666667
# Epoch 253
# Training loss: 1.06825065613
# Training acc: 0.6171875
# Validation acc: 0.666666666667
# Epoch 254
# Training loss: 1.06692874432
# Training acc: 0.621651785714
# Validation acc: 0.635416666667
# Epoch 255
# Training loss: 1.06478488445
# Training acc: 0.609375
# Validation acc: 0.604166666667
# Epoch 256
# Training loss: 1.0415930748
# Training acc: 0.631696428571
# Validation acc: 0.5625
# Epoch 257
# Training loss: 1.06672179699
# Training acc: 0.608258928571
# Validation acc: 0.59375
# Epoch 258
# Training loss: 1.08091247082
# Training acc: 0.606026785714
# Validation acc: 0.635416666667
# Epoch 259
# Training loss: 1.07673966885
# Training acc: 0.611607142857
# Validation acc: 0.666666666667
# Epoch 260
# Training loss: 1.08706235886
# Training acc: 0.598214285714
# Validation acc: 0.71875
# Testing acc: 0.509072580645
# Epoch 261
# Training loss: 1.05345666409
# Training acc: 0.630580357143
# Validation acc: 0.583333333333
# Epoch 262
# Training loss: 1.06954562664
# Training acc: 0.6015625
# Validation acc: 0.645833333333
# Epoch 263
# Training loss: 1.05672693253
# Training acc: 0.623883928571
# Validation acc: 0.604166666667
# Epoch 264
# Training loss: 1.06432306767
# Training acc: 0.603794642857
# Validation acc: 0.666666666667
# Epoch 265
# Training loss: 1.07131314278
# Training acc: 0.618303571429
# Validation acc: 0.59375
# Epoch 266
# Training loss: 1.05779087543
# Training acc: 0.627232142857
# Validation acc: 0.572916666667
# Epoch 267
# Training loss: 1.0551751852
# Training acc: 0.626116071429
# Validation acc: 0.65625
# Epoch 268
# Training loss: 1.07069528103
# Training acc: 0.603794642857
# Validation acc: 0.614583333333
# Epoch 269
# Training loss: 1.04445934296
# Training acc: 0.629464285714
# Validation acc: 0.604166666667
# Epoch 270
# Training loss: 1.05234885216
# Training acc: 0.604910714286
# Validation acc: 0.65625
# Testing acc: 0.508064516129
# Epoch 271
# Training loss: 1.04442000389
# Training acc: 0.609375
# Validation acc: 0.59375
# Epoch 272
# Training loss: 1.0689227581
# Training acc: 0.606026785714
# Validation acc: 0.666666666667
# Epoch 273
# Training loss: 1.03835332394
# Training acc: 0.621651785714
# Validation acc: 0.59375
# Epoch 274
# Training loss: 1.07344710827
# Training acc: 0.609375
# Validation acc: 0.71875
# Epoch 275
# Training loss: 1.06430327892
# Training acc: 0.600446428571
# Validation acc: 0.65625
# Epoch 276
# Training loss: 1.0609126091
# Training acc: 0.609375
# Validation acc: 0.65625
# Epoch 277
# Training loss: 1.05393362045
# Training acc: 0.619419642857
# Validation acc: 0.635416666667
# Epoch 278
# Training loss: 1.0606200695
# Training acc: 0.619419642857
# Validation acc: 0.59375
# Epoch 279
# Training loss: 1.06249308586
# Training acc: 0.609375
# Validation acc: 0.604166666667
# Epoch 280
# Training loss: 1.0585091114
# Training acc: 0.6328125
# Validation acc: 0.5625
# Testing acc: 0.509072580645
# Epoch 281
# Training loss: 1.0544192791
# Training acc: 0.621651785714
# Validation acc: 0.572916666667
# Epoch 282
# Training loss: 1.05981099606
# Training acc: 0.610491071429
# Validation acc: 0.583333333333
# Epoch 283
# Training loss: 1.04934775829
# Training acc: 0.606026785714
# Validation acc: 0.645833333333
# Epoch 284
# Training loss: 1.04487347603
# Training acc: 0.609375
# Validation acc: 0.625
# Epoch 285
# Training loss: 1.05033707619
# Training acc: 0.619419642857
# Validation acc: 0.59375
# Epoch 286
# Training loss: 1.03330254555
# Training acc: 0.627232142857
# Validation acc: 0.625
# Epoch 287
# Training loss: 1.0454018116
# Training acc: 0.622767857143
# Validation acc: 0.677083333333
# Epoch 288
# Training loss: 1.06564903259
# Training acc: 0.607142857143
# Validation acc: 0.677083333333
# Epoch 289
# Training loss: 1.05552697182
# Training acc: 0.620535714286
# Validation acc: 0.572916666667
# Epoch 290
# Training loss: 1.04182624817
# Training acc: 0.621651785714
# Validation acc: 0.65625
# Testing acc: 0.507056451613
# Epoch 291
# Training loss: 1.05612719059
# Training acc: 0.622767857143
# Validation acc: 0.697916666667
# Epoch 292
# Training loss: 1.05875432491
# Training acc: 0.622767857143
# Validation acc: 0.645833333333
# Epoch 293
# Training loss: 1.04374849796
# Training acc: 0.607142857143
# Validation acc: 0.583333333333
# Epoch 294
# Training loss: 1.03759372234
# Training acc: 0.610491071429
# Validation acc: 0.65625
# Epoch 295
# Training loss: 1.04787504673
# Training acc: 0.612723214286
# Validation acc: 0.604166666667
# Epoch 296
# Training loss: 1.03550958633
# Training acc: 0.630580357143
# Validation acc: 0.645833333333
# Epoch 297
# Training loss: 1.05302989483
# Training acc: 0.597098214286
# Validation acc: 0.65625
# Epoch 298
# Training loss: 1.04501831532
# Training acc: 0.607142857143
# Validation acc: 0.614583333333
# Epoch 299
# Training loss: 1.03483808041
# Training acc: 0.638392857143
# Validation acc: 0.645833333333
# Epoch 300
# Training loss: 1.06527757645
# Training acc: 0.604910714286
# Validation acc: 0.6875
# Testing acc: 0.511088709677
# Epoch 301
# Training loss: 1.06116092205
# Training acc: 0.616071428571
# Validation acc: 0.604166666667
# Epoch 302
# Training loss: 1.07981789112
# Training acc: 0.603794642857
# Validation acc: 0.677083333333
# Epoch 303
# Training loss: 1.03132987022
# Training acc: 0.633928571429
# Validation acc: 0.583333333333
# Epoch 304
# Training loss: 1.06737482548
# Training acc: 0.611607142857
# Validation acc: 0.666666666667
# Epoch 305
# Training loss: 1.05655348301
# Training acc: 0.608258928571
# Validation acc: 0.604166666667
# Epoch 306
# Training loss: 1.04820668697
# Training acc: 0.6171875
# Validation acc: 0.677083333333
# Epoch 307
# Training loss: 1.05071568489
# Training acc: 0.612723214286
# Validation acc: 0.666666666667
# Epoch 308
# Training loss: 1.02488160133
# Training acc: 0.635044642857
# Validation acc: 0.604166666667
# Epoch 309
# Training loss: 1.0472587347
# Training acc: 0.612723214286
# Validation acc: 0.708333333333
# Epoch 310
# Training loss: 1.04653704166
# Training acc: 0.616071428571
# Validation acc: 0.645833333333
# Testing acc: 0.511088709677
# Epoch 311
# Training loss: 1.0524276495
# Training acc: 0.613839285714
# Validation acc: 0.635416666667
# Epoch 312
# Training loss: 1.03316318989
# Training acc: 0.613839285714
# Validation acc: 0.614583333333
# Epoch 313
# Training loss: 1.02693676949
# Training acc: 0.639508928571
# Validation acc: 0.625
# Epoch 314
# Training loss: 1.0546387434
# Training acc: 0.597098214286
# Validation acc: 0.677083333333
# Epoch 315
# Training loss: 1.02361571789
# Training acc: 0.623883928571
# Validation acc: 0.604166666667
# Epoch 316
# Training loss: 1.05890750885
# Training acc: 0.606026785714
# Validation acc: 0.6875
# Epoch 317
# Training loss: 1.03537762165
# Training acc: 0.628348214286
# Validation acc: 0.625
# Epoch 318
# Training loss: 1.04430055618
# Training acc: 0.627232142857
# Validation acc: 0.65625
# Epoch 319
# Training loss: 1.04154419899
# Training acc: 0.611607142857
# Validation acc: 0.65625
# Epoch 320
# Training loss: 1.04778039455
# Training acc: 0.610491071429
# Validation acc: 0.635416666667
# Testing acc: 0.506048387097
# Epoch 321
# Training loss: 1.03277528286
# Training acc: 0.618303571429
# Validation acc: 0.645833333333
# Epoch 322
# Training loss: 1.02112114429
# Training acc: 0.613839285714
# Validation acc: 0.5625
# Epoch 323
# Training loss: 1.04324555397
# Training acc: 0.623883928571
# Validation acc: 0.645833333333
# Epoch 324
# Training loss: 1.05020618439
# Training acc: 0.606026785714
# Validation acc: 0.625
# Epoch 325
# Training loss: 1.04421341419
# Training acc: 0.610491071429
# Validation acc: 0.666666666667
# Epoch 326
# Training loss: 1.00896453857
# Training acc: 0.625
# Validation acc: 0.541666666667
# Epoch 327
# Training loss: 1.02830517292
# Training acc: 0.620535714286
# Validation acc: 0.583333333333
# Epoch 328
# Training loss: 1.0279096365
# Training acc: 0.630580357143
# Validation acc: 0.604166666667
# Epoch 329
# Training loss: 1.03732788563
# Training acc: 0.625
# Validation acc: 0.677083333333
# Epoch 330
# Training loss: 1.03395140171
# Training acc: 0.612723214286
# Validation acc: 0.645833333333
# Testing acc: 0.510080645161
# Epoch 331
# Training loss: 1.04216492176
# Training acc: 0.614955357143
# Validation acc: 0.572916666667
# Epoch 332
# Training loss: 1.04647922516
# Training acc: 0.619419642857
# Validation acc: 0.6875
# Epoch 333
# Training loss: 1.03403353691
# Training acc: 0.623883928571
# Validation acc: 0.583333333333
# Epoch 334
# Training loss: 1.01276361942
# Training acc: 0.637276785714
# Validation acc: 0.635416666667
# Epoch 335
# Training loss: 1.04946446419
# Training acc: 0.608258928571
# Validation acc: 0.645833333333
# Epoch 336
# Training loss: 1.03044688702
# Training acc: 0.626116071429
# Validation acc: 0.6875
# Epoch 337
# Training loss: 1.03347110748
# Training acc: 0.622767857143
# Validation acc: 0.625
# Epoch 338
# Training loss: 1.01286911964
# Training acc: 0.6171875
# Validation acc: 0.59375
# Epoch 339
# Training loss: 1.03472745419
# Training acc: 0.6015625
# Validation acc: 0.6875
# Epoch 340
# Training loss: 1.03624904156
# Training acc: 0.616071428571
# Validation acc: 0.572916666667
# Testing acc: 0.503024193548
# Epoch 341
# Training loss: 1.0398324728
# Training acc: 0.626116071429
# Validation acc: 0.666666666667
# Epoch 342
# Training loss: 1.04274916649
# Training acc: 0.607142857143
# Validation acc: 0.6875
# Epoch 343
# Training loss: 1.01580929756
# Training acc: 0.622767857143
# Validation acc: 0.645833333333
# Epoch 344
# Training loss: 1.0324729681
# Training acc: 0.609375
# Validation acc: 0.635416666667
# Epoch 345
# Training loss: 1.04316318035
# Training acc: 0.6171875
# Validation acc: 0.677083333333
# Epoch 346
# Training loss: 1.03759324551
# Training acc: 0.6171875
# Validation acc: 0.65625
# Epoch 347
# Training loss: 1.01545238495
# Training acc: 0.631696428571
# Validation acc: 0.635416666667
# Epoch 348
# Training loss: 1.01834857464
# Training acc: 0.6171875
# Validation acc: 0.635416666667
# Epoch 349
# Training loss: 1.03587758541
# Training acc: 0.626116071429
# Validation acc: 0.614583333333
# Epoch 350
# Training loss: 1.02404773235
# Training acc: 0.623883928571
# Validation acc: 0.6875
# Testing acc: 0.504032258065
# Epoch 351
# Training loss: 1.01825678349
# Training acc: 0.623883928571
# Validation acc: 0.65625
# Epoch 352
# Training loss: 1.01494634151
# Training acc: 0.6171875
# Validation acc: 0.729166666667
# Epoch 353
# Training loss: 1.00042307377
# Training acc: 0.633928571429
# Validation acc: 0.604166666667
# Epoch 354
# Training loss: 1.02334916592
# Training acc: 0.616071428571
# Validation acc: 0.614583333333
# Epoch 355
# Training loss: 1.03045630455
# Training acc: 0.633928571429
# Validation acc: 0.739583333333
# Epoch 356
# Training loss: 1.01433241367
# Training acc: 0.638392857143
# Validation acc: 0.572916666667
# Epoch 357
# Training loss: 1.02098166943
# Training acc: 0.639508928571
# Validation acc: 0.65625
# Epoch 358
# Training loss: 1.02529001236
# Training acc: 0.627232142857
# Validation acc: 0.645833333333
# Epoch 359
# Training loss: 1.03724551201
# Training acc: 0.608258928571
# Validation acc: 0.65625
# Epoch 360
# Training loss: 1.02436292171
# Training acc: 0.629464285714
# Validation acc: 0.708333333333
# Testing acc: 0.5
# Epoch 361
# Training loss: 1.01082777977
# Training acc: 0.636160714286
# Validation acc: 0.635416666667
# Epoch 362
# Training loss: 1.02983820438
# Training acc: 0.614955357143
# Validation acc: 0.697916666667
# Epoch 363
# Training loss: 1.03874647617
# Training acc: 0.621651785714
# Validation acc: 0.635416666667
# Epoch 364
# Training loss: 1.00351941586
# Training acc: 0.638392857143
# Validation acc: 0.65625
# Epoch 365
# Training loss: 1.00445246696
# Training acc: 0.614955357143
# Validation acc: 0.645833333333
# Epoch 366
# Training loss: 1.02105534077
# Training acc: 0.626116071429
# Validation acc: 0.65625
# Epoch 367
# Training loss: 1.0231359005
# Training acc: 0.609375
# Validation acc: 0.666666666667
# Epoch 368
# Training loss: 1.0061186552
# Training acc: 0.626116071429
# Validation acc: 0.604166666667
# Epoch 369
# Training loss: 1.0083245039
# Training acc: 0.638392857143
# Validation acc: 0.635416666667
# Epoch 370
# Training loss: 1.01418578625
# Training acc: 0.631696428571
# Validation acc: 0.59375
# Testing acc: 0.506048387097
# Epoch 371
# Training loss: 0.996153950691
# Training acc: 0.643973214286
# Validation acc: 0.645833333333
# Epoch 372
# Training loss: 1.01701295376
# Training acc: 0.633928571429
# Validation acc: 0.677083333333
# Epoch 373
# Training loss: 1.01795780659
# Training acc: 0.610491071429
# Validation acc: 0.645833333333
# Epoch 374
# Training loss: 1.01942288876
# Training acc: 0.618303571429
# Validation acc: 0.708333333333
# Epoch 375
# Training loss: 0.997310340405
# Training acc: 0.638392857143
# Validation acc: 0.614583333333
# Epoch 376
# Training loss: 0.997315824032
# Training acc: 0.636160714286
# Validation acc: 0.59375
# Epoch 377
# Training loss: 1.00101542473
# Training acc: 0.623883928571
# Validation acc: 0.59375
# Epoch 378
# Training loss: 0.996311485767
# Training acc: 0.631696428571
# Validation acc: 0.677083333333
# Epoch 379
# Training loss: 1.00249421597
# Training acc: 0.630580357143
# Validation acc: 0.604166666667
# Epoch 380
# Training loss: 1.00556206703
# Training acc: 0.629464285714
# Validation acc: 0.635416666667
# Testing acc: 0.502016129032
# Epoch 381
# Training loss: 1.00305879116
# Training acc: 0.655133928571
# Validation acc: 0.666666666667
# Epoch 382
# Training loss: 1.01177537441
# Training acc: 0.626116071429
# Validation acc: 0.635416666667
# Epoch 383
# Training loss: 0.995523393154
# Training acc: 0.6328125
# Validation acc: 0.677083333333
# Epoch 384
# Training loss: 1.02832734585
# Training acc: 0.616071428571
# Validation acc: 0.71875
# Epoch 385
# Training loss: 1.00230097771
# Training acc: 0.630580357143
# Validation acc: 0.666666666667
# Epoch 386
# Training loss: 0.986529290676
# Training acc: 0.641741071429
# Validation acc: 0.604166666667
# Epoch 387
# Training loss: 0.993658483028
# Training acc: 0.623883928571
# Validation acc: 0.677083333333
# Epoch 388
# Training loss: 0.992553651333
# Training acc: 0.628348214286
# Validation acc: 0.677083333333
# Epoch 389
# Training loss: 0.980458378792
# Training acc: 0.635044642857
# Validation acc: 0.5625
# Epoch 390
# Training loss: 1.02082788944
# Training acc: 0.628348214286
# Validation acc: 0.729166666667
# Testing acc: 0.504032258065
# Epoch 391
# Training loss: 0.979222238064
# Training acc: 0.657366071429
# Validation acc: 0.583333333333
# Epoch 392
# Training loss: 1.00148189068
# Training acc: 0.621651785714
# Validation acc: 0.59375
# Epoch 393
# Training loss: 1.00398933887
# Training acc: 0.6328125
# Validation acc: 0.6875
# Epoch 394
# Training loss: 1.01337516308
# Training acc: 0.629464285714
# Validation acc: 0.677083333333
# Epoch 395
# Training loss: 1.01090538502
# Training acc: 0.641741071429
# Validation acc: 0.65625
# Epoch 396
# Training loss: 0.988890349865
# Training acc: 0.647321428571
# Validation acc: 0.614583333333
# Epoch 397
# Training loss: 1.0218732357
# Training acc: 0.625
# Validation acc: 0.739583333333
# Epoch 398
# Training loss: 0.990546524525
# Training acc: 0.645089285714
# Validation acc: 0.625
# Epoch 399
# Training loss: 0.988590240479
# Training acc: 0.655133928571
# Validation acc: 0.614583333333
# Epoch 400
# Training loss: 0.986988902092
# Training acc: 0.635044642857
# Validation acc: 0.635416666667
# Testing acc: 0.497983870968
# Epoch 401
# Training loss: 0.979535639286
# Training acc: 0.646205357143
# Validation acc: 0.59375
# Epoch 402
# Training loss: 0.990546584129
# Training acc: 0.633928571429
# Validation acc: 0.65625
# Epoch 403
# Training loss: 1.01051366329
# Training acc: 0.622767857143
# Validation acc: 0.6875
# Epoch 404
# Training loss: 0.974487006664
# Training acc: 0.642857142857
# Validation acc: 0.604166666667
# Epoch 405
# Training loss: 1.00514531136
# Training acc: 0.6328125
# Validation acc: 0.71875
# Epoch 406
# Training loss: 0.981414139271
# Training acc: 0.631696428571
# Validation acc: 0.645833333333
# Epoch 407
# Training loss: 0.988015115261
# Training acc: 0.635044642857
# Validation acc: 0.65625
# Epoch 408
# Training loss: 0.969860136509
# Training acc: 0.650669642857
# Validation acc: 0.635416666667
# Epoch 409
# Training loss: 1.00066912174
# Training acc: 0.625
# Validation acc: 0.645833333333
# Epoch 410
# Training loss: 1.01446831226
# Training acc: 0.637276785714
# Validation acc: 0.739583333333
# Testing acc: 0.51310483871
# Epoch 411
# Training loss: 0.982740819454
# Training acc: 0.638392857143
# Validation acc: 0.614583333333
# Epoch 412
# Training loss: 0.990061223507
# Training acc: 0.626116071429
# Validation acc: 0.677083333333
# Epoch 413
# Training loss: 0.982432305813
# Training acc: 0.638392857143
# Validation acc: 0.6875
# Epoch 414
# Training loss: 0.98023045063
# Training acc: 0.636160714286
# Validation acc: 0.59375
# Epoch 415
# Training loss: 1.00381493568
# Training acc: 0.623883928571
# Validation acc: 0.708333333333
# Epoch 416
# Training loss: 0.985498011112
# Training acc: 0.642857142857
# Validation acc: 0.604166666667
# Epoch 417
# Training loss: 0.99992275238
# Training acc: 0.636160714286
# Validation acc: 0.65625
# Epoch 418
# Training loss: 0.987186431885
# Training acc: 0.637276785714
# Validation acc: 0.645833333333
# Epoch 419
# Training loss: 0.99297440052
# Training acc: 0.640625
# Validation acc: 0.697916666667
# Epoch 420
# Training loss: 0.987948834896
# Training acc: 0.654017857143
# Validation acc: 0.697916666667
# Testing acc: 0.497983870968
# Epoch 421
# Training loss: 0.985319495201
# Training acc: 0.635044642857
# Validation acc: 0.677083333333
# Epoch 422
# Training loss: 0.978601455688
# Training acc: 0.640625
# Validation acc: 0.65625
# Epoch 423
# Training loss: 0.98290348053
# Training acc: 0.643973214286
# Validation acc: 0.614583333333
# Epoch 424
# Training loss: 0.989880681038
# Training acc: 0.6328125
# Validation acc: 0.666666666667
# Epoch 425
# Training loss: 0.993277072906
# Training acc: 0.636160714286
# Validation acc: 0.677083333333
# Epoch 426
# Training loss: 0.969156444073
# Training acc: 0.645089285714
# Validation acc: 0.604166666667
# Epoch 427
# Training loss: 0.98019438982
# Training acc: 0.638392857143
# Validation acc: 0.645833333333
# Epoch 428
# Training loss: 0.992581903934
# Training acc: 0.631696428571
# Validation acc: 0.697916666667
# Epoch 429
# Training loss: 0.986097693443
# Training acc: 0.629464285714
# Validation acc: 0.729166666667
# Epoch 430
# Training loss: 0.963844835758
# Training acc: 0.659598214286
# Validation acc: 0.677083333333
# Testing acc: 0.505040322581
# Epoch 431
# Training loss: 0.992897689342
# Training acc: 0.612723214286
# Validation acc: 0.614583333333
# Epoch 432
# Training loss: 0.969417095184
# Training acc: 0.6484375
# Validation acc: 0.635416666667
# Epoch 433
# Training loss: 1.00546443462
# Training acc: 0.614955357143
# Validation acc: 0.729166666667
# Epoch 434
# Training loss: 0.989765822887
# Training acc: 0.640625
# Validation acc: 0.729166666667
# Epoch 435
# Training loss: 1.00671303272
# Training acc: 0.628348214286
# Validation acc: 0.708333333333
# Epoch 436
# Training loss: 0.968338131905
# Training acc: 0.640625
# Validation acc: 0.65625
# Epoch 437
# Training loss: 0.958124935627
# Training acc: 0.647321428571
# Validation acc: 0.614583333333
# Epoch 438
# Training loss: 0.983268916607
# Training acc: 0.6484375
# Validation acc: 0.708333333333
# Epoch 439
# Training loss: 0.960683822632
# Training acc: 0.647321428571
# Validation acc: 0.65625
# Epoch 440
# Training loss: 0.989982783794
# Training acc: 0.6328125
# Validation acc: 0.677083333333
# Testing acc: 0.510080645161
# Epoch 441
# Training loss: 0.963854014874
# Training acc: 0.658482142857
# Validation acc: 0.604166666667
# Epoch 442
# Training loss: 0.9626070261
# Training acc: 0.631696428571
# Validation acc: 0.697916666667
# Epoch 443
# Training loss: 0.98214417696
# Training acc: 0.641741071429
# Validation acc: 0.677083333333
# Epoch 444
# Training loss: 0.986625611782
# Training acc: 0.637276785714
# Validation acc: 0.666666666667
# Epoch 445
# Training loss: 0.978908658028
# Training acc: 0.628348214286
# Validation acc: 0.645833333333
# Epoch 446
# Training loss: 0.966421186924
# Training acc: 0.643973214286
# Validation acc: 0.645833333333
# Epoch 447
# Training loss: 0.980894505978
# Training acc: 0.635044642857
# Validation acc: 0.708333333333
# Epoch 448
# Training loss: 0.964841842651
# Training acc: 0.642857142857
# Validation acc: 0.65625
# Epoch 449
# Training loss: 0.958398163319
# Training acc: 0.650669642857
# Validation acc: 0.604166666667
# Epoch 450
# Training loss: 0.970409989357
# Training acc: 0.649553571429
# Validation acc: 0.697916666667
# Testing acc: 0.507056451613
# Epoch 451
# Training loss: 0.958163738251
# Training acc: 0.651785714286
# Validation acc: 0.625
# Epoch 452
# Training loss: 0.973717987537
# Training acc: 0.6328125
# Validation acc: 0.697916666667
# Epoch 453
# Training loss: 0.966865718365
# Training acc: 0.652901785714
# Validation acc: 0.645833333333
# Epoch 454
# Training loss: 0.9716116786
# Training acc: 0.642857142857
# Validation acc: 0.6875
# Epoch 455
# Training loss: 0.955627262592
# Training acc: 0.643973214286
# Validation acc: 0.625
# Epoch 456
# Training loss: 0.967703998089
# Training acc: 0.645089285714
# Validation acc: 0.65625
# Epoch 457
# Training loss: 0.982392370701
# Training acc: 0.635044642857
# Validation acc: 0.71875
# Epoch 458
# Training loss: 0.96485966444
# Training acc: 0.637276785714
# Validation acc: 0.697916666667
# Epoch 459
# Training loss: 0.966719567776
# Training acc: 0.646205357143
# Validation acc: 0.666666666667
# Epoch 460
# Training loss: 0.973277211189
# Training acc: 0.646205357143
# Validation acc: 0.6875
# Testing acc: 0.5
# Epoch 461
# Training loss: 0.995593726635
# Training acc: 0.619419642857
# Validation acc: 0.739583333333
# Epoch 462
# Training loss: 0.97220480442
# Training acc: 0.645089285714
# Validation acc: 0.729166666667
# Epoch 463
# Training loss: 0.940043568611
# Training acc: 0.646205357143
# Validation acc: 0.635416666667
# Epoch 464
# Training loss: 0.959654867649
# Training acc: 0.633928571429
# Validation acc: 0.677083333333
# Epoch 465
# Training loss: 0.997159540653
# Training acc: 0.626116071429
# Validation acc: 0.760416666667
# Epoch 466
# Training loss: 0.966305196285
# Training acc: 0.6484375
# Validation acc: 0.677083333333
# Epoch 467
# Training loss: 0.948240339756
# Training acc: 0.662946428571
# Validation acc: 0.635416666667
# Epoch 468
# Training loss: 0.937460541725
# Training acc: 0.642857142857
# Validation acc: 0.645833333333
# Epoch 469
# Training loss: 0.943117082119
# Training acc: 0.683035714286
# Validation acc: 0.645833333333
# Epoch 470
# Training loss: 0.947755157948
# Training acc: 0.662946428571
# Validation acc: 0.614583333333
# Testing acc: 0.506048387097
# Epoch 471
# Training loss: 0.968658030033
# Training acc: 0.638392857143
# Validation acc: 0.697916666667
# Epoch 472
# Training loss: 0.971851229668
# Training acc: 0.645089285714
# Validation acc: 0.708333333333
# Epoch 473
# Training loss: 0.965041995049
# Training acc: 0.641741071429
# Validation acc: 0.6875
# Epoch 474
# Training loss: 0.938084304333
# Training acc: 0.657366071429
# Validation acc: 0.645833333333
# Epoch 475
# Training loss: 0.936843037605
# Training acc: 0.643973214286
# Validation acc: 0.666666666667
# Epoch 476
# Training loss: 0.958493113518
# Training acc: 0.636160714286
# Validation acc: 0.697916666667
# Epoch 477
# Training loss: 0.962119877338
# Training acc: 0.638392857143
# Validation acc: 0.708333333333
# Epoch 478
# Training loss: 0.935980379581
# Training acc: 0.668526785714
# Validation acc: 0.645833333333
# Epoch 479
# Training loss: 0.946974754333
# Training acc: 0.665178571429
# Validation acc: 0.645833333333
# Epoch 480
# Training loss: 0.951178431511
# ...
# Epoch 338
# Training loss: 1.20165383816
# Training acc: 0.600446428571
# Validation acc: 0.572916666667
# Epoch 339
# Training loss: 1.19327843189
# Training acc: 0.6015625
# Validation acc: 0.604166666667
# Epoch 340
# Training loss: 1.18653082848
# Training acc: 0.6015625
# Validation acc: 0.65625
# Testing acc: 0.345766129032
# Epoch 341
# Training loss: 1.20456087589
# Training acc: 0.583705357143
# Validation acc: 0.65625
# Epoch 342
# Training loss: 1.18688964844
# Training acc: 0.597098214286
# Validation acc: 0.604166666667
# Epoch 343
# Training loss: 1.17329156399
# Training acc: 0.616071428571
# Validation acc: 0.572916666667
# Epoch 344
# Training loss: 1.20248198509
# Training acc: 0.599330357143
# Validation acc: 0.697916666667
# Epoch 345
# Training loss: 1.17447221279
# Training acc: 0.6015625
# Validation acc: 0.53125
# Epoch 346
# Training loss: 1.18511509895
# Training acc: 0.592633928571
# Validation acc: 0.666666666667
# Epoch 347
# Training loss: 1.17095923424
# Training acc: 0.599330357143
# Validation acc: 0.59375
# Epoch 348
# Training loss: 1.19593024254
# Training acc: 0.588169642857
# Validation acc: 0.645833333333
# Epoch 349
# Training loss: 1.17657339573
# Training acc: 0.59375
# Validation acc: 0.604166666667
# Epoch 350
# Training loss: 1.16694664955
# Training acc: 0.606026785714
# Validation acc: 0.59375
# Testing acc: 0.333669354839
# Epoch 351
# Training loss: 1.17279136181
# Training acc: 0.611607142857
# Validation acc: 0.708333333333
# Epoch 352
# Training loss: 1.16834676266
# Training acc: 0.602678571429
# Validation acc: 0.625
# Epoch 353
# Training loss: 1.16503798962
# Training acc: 0.611607142857
# Validation acc: 0.541666666667
# Epoch 354
# Training loss: 1.172118783
# Training acc: 0.609375
# Validation acc: 0.541666666667
# Epoch 355
# Training loss: 1.15996837616
# Training acc: 0.612723214286
# Validation acc: 0.583333333333
# Epoch 356
# Training loss: 1.13297319412
# Training acc: 0.611607142857
# Validation acc: 0.552083333333
# Epoch 357
# Training loss: 1.19368636608
# Training acc: 0.584821428571
# Validation acc: 0.697916666667
# Epoch 358
# Training loss: 1.15657114983
# Training acc: 0.609375
# Validation acc: 0.604166666667
# Epoch 359
# Training loss: 1.17798006535
# Training acc: 0.6015625
# Validation acc: 0.635416666667
# Epoch 360
# Training loss: 1.16525197029
# Training acc: 0.619419642857
# Validation acc: 0.5625
# Testing acc: 0.333669354839
# Epoch 361
# Training loss: 1.15567493439
# Training acc: 0.602678571429
# Validation acc: 0.65625
# Epoch 362
# Training loss: 1.15304005146
# Training acc: 0.600446428571
# Validation acc: 0.572916666667
# Epoch 363
# Training loss: 1.17073762417
# Training acc: 0.607142857143
# Validation acc: 0.697916666667
# Epoch 364
# Training loss: 1.17355549335
# Training acc: 0.604910714286
# Validation acc: 0.645833333333
# Epoch 365
# Training loss: 1.17891180515
# Training acc: 0.598214285714
# Validation acc: 0.572916666667
# Epoch 366
# Training loss: 1.17221355438
# Training acc: 0.620535714286
# Validation acc: 0.645833333333
# Epoch 367
# Training loss: 1.16212761402
# Training acc: 0.608258928571
# Validation acc: 0.59375
# Epoch 368
# Training loss: 1.15186786652
# Training acc: 0.619419642857
# Validation acc: 0.65625
# Epoch 369
# Training loss: 1.12626719475
# Training acc: 0.618303571429
# Validation acc: 0.614583333333
# Epoch 370
# Training loss: 1.14619767666
# Training acc: 0.604910714286
# Validation acc: 0.6875
# Testing acc: 0.332661290323
# Epoch 371
# Training loss: 1.14490783215
# Training acc: 0.609375
# Validation acc: 0.552083333333
# Epoch 372
# Training loss: 1.16331744194
# Training acc: 0.606026785714
# Validation acc: 0.697916666667
# Epoch 373
# Training loss: 1.13580453396
# Training acc: 0.626116071429
# Validation acc: 0.65625
# Epoch 374
# Training loss: 1.15465915203
# Training acc: 0.612723214286
# Validation acc: 0.677083333333
# Epoch 375
# Training loss: 1.13000714779
# Training acc: 0.626116071429
# Validation acc: 0.625
# Epoch 376
# Training loss: 1.15349113941
# Training acc: 0.6015625
# Validation acc: 0.635416666667
# Epoch 377
# Training loss: 1.14329171181
# Training acc: 0.606026785714
# Validation acc: 0.625
# Epoch 378
# Training loss: 1.15634417534
# Training acc: 0.600446428571
# Validation acc: 0.645833333333
# Epoch 379
# Training loss: 1.11583316326
# Training acc: 0.613839285714
# Validation acc: 0.59375
# Epoch 380
# Training loss: 1.14662861824
# Training acc: 0.618303571429
# Validation acc: 0.697916666667
# Testing acc: 0.333669354839
# Epoch 381
# Training loss: 1.12877631187
# Training acc: 0.613839285714
# Validation acc: 0.666666666667
# Epoch 382
# Training loss: 1.10498845577
# Training acc: 0.630580357143
# Validation acc: 0.520833333333
# Epoch 383
# Training loss: 1.12764179707
# Training acc: 0.623883928571
# Validation acc: 0.635416666667
# Epoch 384
# Training loss: 1.1140100956
# Training acc: 0.627232142857
# Validation acc: 0.625
# Epoch 385
# Training loss: 1.14937877655
# Training acc: 0.608258928571
# Validation acc: 0.65625
# Epoch 386
# Training loss: 1.13296580315
# Training acc: 0.607142857143
# Validation acc: 0.666666666667
# Epoch 387
# Training loss: 1.12032783031
# Training acc: 0.621651785714
# Validation acc: 0.625
# Epoch 388
# Training loss: 1.10380518436
# Training acc: 0.623883928571
# Validation acc: 0.552083333333
# Epoch 389
# Training loss: 1.11685335636
# Training acc: 0.639508928571
# Validation acc: 0.635416666667
# Epoch 390
# Training loss: 1.11196923256
# Training acc: 0.628348214286
# Validation acc: 0.645833333333
# Testing acc: 0.336693548387
# Epoch 391
# Training loss: 1.13069701195
# Training acc: 0.614955357143
# Validation acc: 0.625
# Epoch 392
# Training loss: 1.13612043858
# Training acc: 0.608258928571
# Validation acc: 0.65625
# Epoch 393
# Training loss: 1.11450004578
# Training acc: 0.629464285714
# Validation acc: 0.645833333333
# Epoch 394
# Training loss: 1.10947239399
# Training acc: 0.625
# Validation acc: 0.677083333333
# Epoch 395
# Training loss: 1.11323237419
# Training acc: 0.637276785714
# Validation acc: 0.708333333333
# Epoch 396
# Training loss: 1.11789190769
# Training acc: 0.6328125
# Validation acc: 0.65625
# Epoch 397
# Training loss: 1.10590434074
# Training acc: 0.606026785714
# Validation acc: 0.645833333333
# Epoch 398
# Training loss: 1.111546278
# Training acc: 0.604910714286
# Validation acc: 0.708333333333
# Epoch 399
# Training loss: 1.08523988724
# Training acc: 0.639508928571
# Validation acc: 0.635416666667
# Epoch 400
# Training loss: 1.09775221348
# Training acc: 0.662946428571
# Validation acc: 0.645833333333
# Testing acc: 0.331653225806
# Epoch 401
# Training loss: 1.10956978798
# Training acc: 0.639508928571
# Validation acc: 0.708333333333
# Epoch 402
# Training loss: 1.05575120449
# Training acc: 0.667410714286
# Validation acc: 0.541666666667
# Epoch 403
# Training loss: 1.10029423237
# Training acc: 0.640625
# Validation acc: 0.635416666667
# Epoch 404
# Training loss: 1.10651576519
# Training acc: 0.609375
# Validation acc: 0.71875
# Epoch 405
# Training loss: 1.1065672636
# Training acc: 0.626116071429
# Validation acc: 0.697916666667
# Epoch 406
# Training loss: 1.09810221195
# Training acc: 0.642857142857
# Validation acc: 0.666666666667
# Epoch 407
# Training loss: 1.08261883259
# Training acc: 0.649553571429
# Validation acc: 0.510416666667
# Epoch 408
# Training loss: 1.06004416943
# Training acc: 0.640625
# Validation acc: 0.666666666667
# Epoch 409
# Training loss: 1.09362566471
# Training acc: 0.633928571429
# Validation acc: 0.666666666667
# Epoch 410
# Training loss: 1.09093391895
# Training acc: 0.639508928571
# Validation acc: 0.697916666667
# Testing acc: 0.340725806452
# Epoch 411
# Training loss: 1.08697247505
# Training acc: 0.628348214286
# Validation acc: 0.645833333333
# Epoch 412
# Training loss: 1.04855823517
# Training acc: 0.650669642857
# Validation acc: 0.604166666667
# Epoch 413
# Training loss: 1.08660805225
# Training acc: 0.646205357143
# Validation acc: 0.59375
# Epoch 414
# Training loss: 1.07924568653
# Training acc: 0.655133928571
# Validation acc: 0.614583333333
# Epoch 415
# Training loss: 1.03486597538
# Training acc: 0.658482142857
# Validation acc: 0.583333333333
# Epoch 416
# Training loss: 1.07872891426
# Training acc: 0.640625
# Validation acc: 0.645833333333
# Epoch 417
# Training loss: 1.09971010685
# Training acc: 0.625
# Validation acc: 0.677083333333
# Epoch 418
# Training loss: 1.10146307945
# Training acc: 0.638392857143
# Validation acc: 0.71875
# Epoch 419
# Training loss: 1.0593650341
# Training acc: 0.655133928571
# Validation acc: 0.645833333333
# Epoch 420
# Training loss: 1.09026551247
# Training acc: 0.639508928571
# Validation acc: 0.75
# Testing acc: 0.32560483871
# Epoch 421
# Training loss: 1.05304145813
# Training acc: 0.650669642857
# Validation acc: 0.65625
# Epoch 422
# Training loss: 1.08115899563
# Training acc: 0.639508928571
# Validation acc: 0.71875
# Epoch 423
# Training loss: 1.06797707081
# Training acc: 0.655133928571
# Validation acc: 0.71875
# Epoch 424
# Training loss: 1.06711220741
# Training acc: 0.649553571429
# Validation acc: 0.666666666667
# Epoch 425
# Training loss: 1.0759396553
# Training acc: 0.652901785714
# Validation acc: 0.645833333333
# Epoch 426
# Training loss: 1.0632109642
# Training acc: 0.647321428571
# Validation acc: 0.75
# Epoch 427
# Training loss: 1.06743395329
# Training acc: 0.65625
# Validation acc: 0.697916666667
# Epoch 428
# Training loss: 1.07782256603
# Training acc: 0.643973214286
# Validation acc: 0.635416666667
# Epoch 429
# Training loss: 1.04359090328
# Training acc: 0.657366071429
# Validation acc: 0.625
# Epoch 430
# Training loss: 1.0549916029
# Training acc: 0.652901785714
# Validation acc: 0.75
# Testing acc: 0.338709677419
# Epoch 431
# Training loss: 1.03593635559
# Training acc: 0.6484375
# Validation acc: 0.635416666667
# Epoch 432
# Training loss: 1.05088508129
# Training acc: 0.65625
# Validation acc: 0.614583333333
# Epoch 433
# Training loss: 1.04677951336
# Training acc: 0.652901785714
# Validation acc: 0.729166666667
# Epoch 434
# Training loss: 1.05017864704
# Training acc: 0.659598214286
# Validation acc: 0.666666666667
# Epoch 435
# Training loss: 1.06552612782
# Training acc: 0.658482142857
# Validation acc: 0.666666666667
# Epoch 436
# Training loss: 1.05574631691
# Training acc: 0.6484375
# Validation acc: 0.739583333333
# Epoch 437
# Training loss: 1.04492223263
# Training acc: 0.668526785714
# Validation acc: 0.71875
# Epoch 438
# Training loss: 1.06414330006
# Training acc: 0.643973214286
# Validation acc: 0.677083333333
# Epoch 439
# Training loss: 1.03683018684
# Training acc: 0.655133928571
# Validation acc: 0.614583333333
# Epoch 440
# Training loss: 1.04050135612
# Training acc: 0.659598214286
# Validation acc: 0.65625
# Testing acc: 0.33064516129
# Epoch 441
# Training loss: 1.0722951889
# Training acc: 0.645089285714
# Validation acc: 0.75
# Epoch 442
# Training loss: 1.05550420284
# Training acc: 0.650669642857
# Validation acc: 0.71875
# Epoch 443
# Training loss: 1.01013791561
# Training acc: 0.659598214286
# Validation acc: 0.53125
# Epoch 444
# Training loss: 1.03333747387
# Training acc: 0.660714285714
# Validation acc: 0.677083333333
# Epoch 445
# Training loss: 1.01436543465
# Training acc: 0.690848214286
# Validation acc: 0.614583333333
# Epoch 446
# Training loss: 1.03811502457
# Training acc: 0.659598214286
# Validation acc: 0.71875
# Epoch 447
# Training loss: 1.00819456577
# Training acc: 0.671875
# Validation acc: 0.625
# Epoch 448
# Training loss: 1.0500138998
# Training acc: 0.646205357143
# Validation acc: 0.75
# Epoch 449
# Training loss: 1.03962635994
# Training acc: 0.652901785714
# Validation acc: 0.760416666667
# Epoch 450
# Training loss: 1.00297987461
# Training acc: 0.675223214286
# Validation acc: 0.666666666667
# Testing acc: 0.337701612903
# Epoch 451
# Training loss: 1.0526278019
# Training acc: 0.672991071429
# Validation acc: 0.6875
# Epoch 452
# Training loss: 1.0212495327
# Training acc: 0.668526785714
# Validation acc: 0.6875
# Epoch 453
# Training loss: 1.03244435787
# Training acc: 0.659598214286
# Validation acc: 0.6875
# Epoch 454
# Training loss: 1.0250992775
# Training acc: 0.6640625
# Validation acc: 0.6875
# Epoch 455
# Training loss: 1.02185547352
# Training acc: 0.651785714286
# Validation acc: 0.708333333333
# Epoch 456
# Training loss: 1.01679778099
# Training acc: 0.671875
# Validation acc: 0.677083333333
# Epoch 457
# Training loss: 1.02012729645
# Training acc: 0.658482142857
# Validation acc: 0.697916666667
# Epoch 458
# Training loss: 1.01487660408
# Training acc: 0.670758928571
# Validation acc: 0.677083333333
# Epoch 459
# Training loss: 1.00691068172
# Training acc: 0.671875
# Validation acc: 0.625
# Epoch 460
# Training loss: 1.01905703545
# Training acc: 0.667410714286
# Validation acc: 0.739583333333
# Testing acc: 0.33064516129
# Epoch 461
# Training loss: 1.02894771099
# Training acc: 0.658482142857
# Validation acc: 0.708333333333
# Epoch 462
# Training loss: 1.00942730904
# Training acc: 0.652901785714
# Validation acc: 0.666666666667
# Epoch 463
# Training loss: 1.04010772705
# Training acc: 0.646205357143
# Validation acc: 0.697916666667
# Epoch 464
# Training loss: 1.02020680904
# Training acc: 0.659598214286
# Validation acc: 0.739583333333
# Epoch 465
# Training loss: 1.03216135502
# Training acc: 0.6796875
# Validation acc: 0.75
# Epoch 466
# Training loss: 1.00086033344
# Training acc: 0.677455357143
# Validation acc: 0.697916666667
# Epoch 467
# Training loss: 1.0114531517
# Training acc: 0.665178571429
# Validation acc: 0.604166666667
# Epoch 468
# Training loss: 1.00496459007
# Training acc: 0.675223214286
# Validation acc: 0.739583333333
# Epoch 469
# Training loss: 1.00288784504
# Training acc: 0.672991071429
# Validation acc: 0.6875
# Epoch 470
# Training loss: 1.00366508961
# Training acc: 0.672991071429
# Validation acc: 0.666666666667
# Testing acc: 0.331653225806
# Epoch 471
# Training loss: 1.01531612873
# Training acc: 0.670758928571
# Validation acc: 0.791666666667
# Epoch 472
# Training loss: 0.980104148388
# Training acc: 0.691964285714
# Validation acc: 0.625
# Epoch 473
# Training loss: 0.967244684696
# Training acc: 0.680803571429
# Validation acc: 0.666666666667
# Epoch 474
# Training loss: 0.996011257172
# Training acc: 0.685267857143
# Validation acc: 0.708333333333
# Epoch 475
# Training loss: 1.0120652914
# Training acc: 0.676339285714
# Validation acc: 0.770833333333
# Epoch 476
# Training loss: 0.993618011475
# Training acc: 0.670758928571
# Validation acc: 0.708333333333
# Epoch 477
# Training loss: 0.987324118614
# Training acc: 0.686383928571
# Validation acc: 0.71875
# Epoch 478
# Training loss: 0.968964517117
# Training acc: 0.668526785714
# Validation acc: 0.6875
# Epoch 479
# Training loss: 0.991216599941
# Training acc: 0.689732142857
# Validation acc: 0.760416666667
# Epoch 480
# Training loss: 0.994553387165
# Training acc: 0.665178571429
# Validation acc: 0.71875
# Testing acc: 0.32560483871
# Epoch 481
# Training loss: 0.98065584898
# Training acc: 0.680803571429
# Validation acc: 0.71875
# Epoch 482
# Training loss: 0.987958371639
# Training acc: 0.685267857143
# Validation acc: 0.770833333333
# Epoch 483
# Training loss: 0.986222565174
# Training acc: 0.675223214286
# Validation acc: 0.770833333333
# Epoch 484
# Training loss: 0.976587831974
# Training acc: 0.680803571429
# Validation acc: 0.59375
# Epoch 485
# Training loss: 0.980648696423
# Training acc: 0.676339285714
# Validation acc: 0.708333333333
# Epoch 486
# Training loss: 0.974170267582
# Training acc: 0.689732142857
# Validation acc: 0.65625
# Epoch 487
# Training loss: 0.954804837704
# Training acc: 0.697544642857
# Validation acc: 0.572916666667
# Epoch 488
# Training loss: 0.969200670719
# Training acc: 0.689732142857
# Validation acc: 0.666666666667
# Epoch 489
# Training loss: 0.991306602955
# Training acc: 0.671875
# Validation acc: 0.833333333333
# Epoch 490
# Training loss: 0.963316440582
# Training acc: 0.6796875
# Validation acc: 0.708333333333
# Testing acc: 0.333669354839
# Epoch 491
# Training loss: 0.969796597958
# Training acc: 0.6796875
# Validation acc: 0.677083333333
# Epoch 492
# Training loss: 0.983035027981
# Training acc: 0.702008928571
# Validation acc: 0.78125
# Epoch 493
# Training loss: 0.95863622427
# Training acc: 0.683035714286
# Validation acc: 0.71875
# Epoch 494
# Training loss: 0.937462449074
# Training acc: 0.7109375
# Validation acc: 0.65625
# Epoch 495
# Training loss: 0.954792618752
# Training acc: 0.712053571429
# Validation acc: 0.739583333333
# Epoch 496
# Training loss: 0.928057491779
# Training acc: 0.702008928571
# Validation acc: 0.5625
# Epoch 497
# Training loss: 0.949608981609
# Training acc: 0.690848214286
# Validation acc: 0.697916666667
# Epoch 498
# Training loss: 0.957750976086
# Training acc: 0.691964285714
# Validation acc: 0.75
# Epoch 499
# Training loss: 0.97633677721
# Training acc: 0.688616071429
# Validation acc: 0.71875
# Epoch 500
# Training loss: 0.96906119585
# Training acc: 0.691964285714
# Validation acc: 0.729166666667
# Testing acc: 0.329637096774
