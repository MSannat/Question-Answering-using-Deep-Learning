# %% [markdown]
# ## Question Answering using Deep Learning Dynamic Memory Networks Model3
#
# Modified codebase from: Dynamic Memory Networks in TensorFlow, https://github.com/barronalex/Dynamic-Memory-Networks-in-TensorFlow.

# %% [markdown]
# #### Implementation of DMN3 model as desribed in the paper: Caiming Xiong, Stephen Merity, Richard Socher Dynamic Memory Networks for Visual and Textual Question Answering https://arxiv.org/abs/1603.01417

# %% [markdown]
# <img src="3DMNplusModels.png" alt="Dynamic Memory Networks Models" height="400" width="400">

# %%
# !python dmn_train.py -b 1
# Out:
# Training DMN plus on babi task 1
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa1_single-supporting-fact_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa1_single-supporting-fact_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-14 21:39:54.307496: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-14 21:39:54.307520: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 1
# Out:
# Testing DMN plus on babi task 1
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa1_single-supporting-fact_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa1_single-supporting-fact_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-14 22:35:48.111018: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-14 22:35:48.111041: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_train.py -b 2
# Out:
# Training DMN plus on babi task 2
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa2_two-supporting-facts_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa2_two-supporting-facts_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-16 15:05:43.954893: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 15:05:43.954916: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 2
# Out:
# Testing DMN plus on babi task 2
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa2_two-supporting-facts_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa2_two-supporting-facts_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-16 17:10:19.106114: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 17:10:19.106158: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_train.py -b 3
# Out:
# Training DMN plus on babi task 3
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa3_three-supporting-facts_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa3_three-supporting-facts_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-16 17:24:56.847725: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 17:24:56.847749: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 3
# Out:
# Testing DMN plus on babi task 3
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa3_three-supporting-facts_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa3_three-supporting-facts_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-16 18:47:47.429778: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 18:47:47.429802: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_train.py -b 4
# Out:
# Training DMN plus on babi task 4
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa4_two-arg-relations_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa4_two-arg-relations_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 01:49:15.461133: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 01:49:15.461155: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 4
# Out:
# Testing DMN plus on babi task 4
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa4_two-arg-relations_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa4_two-arg-relations_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 02:14:01.208314: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 02:14:01.208337: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 5
# Out:
# Training DMN plus on babi task 5
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa5_three-arg-relations_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa5_three-arg-relations_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 02:15:14.579622: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 02:15:14.579644: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 5
# Out:
# Testing DMN plus on babi task 5
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa5_three-arg-relations_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa5_three-arg-relations_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 04:52:00.241576: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 04:52:00.241600: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 6
# Out:
# Training DMN plus on babi task 6
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa6_yes-no-questions_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa6_yes-no-questions_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 04:52:43.689177: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 04:52:43.689201: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 6
# Out:
# Testing DMN plus on babi task 6
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa6_yes-no-questions_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa6_yes-no-questions_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 08:38:43.995423: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 08:38:43.995448: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 7
# Out:
# Training DMN plus on babi task 7
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa7_counting_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa7_counting_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 08:39:33.897366: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 08:39:33.897390: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> starting training
# ...

# %%
# !python dmn_test.py -b 7
# Out:
# Testing DMN plus on babi task 7
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa7_counting_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa7_counting_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 10:29:02.354577: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 10:29:02.354602: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ==> running DMN
# ...

# %%
# !python dmn_train.py -b 8
# Out:
# Training DMN plus on babi task 8
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa8_lists-sets_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa8_lists-sets_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 20:39:41.785480: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 20:39:41.785512: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> starting training
# ...

# %%
# !python dmn_test.py -b 8
# Out:
# Testing DMN plus on babi task 8
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa8_lists-sets_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa8_lists-sets_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 21:57:11.738704: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 21:57:11.738730: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ==> running DMN
# ...

# %%
# !python dmn_train.py -b 9
# Out:
# Training DMN plus on babi task 9
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa9_simple-negation_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa9_simple-negation_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 21:57:50.391992: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 21:57:50.392015: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 9
# Out:
# Testing DMN plus on babi task 9
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa9_simple-negation_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa9_simple-negation_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 22:09:03.964068: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 22:09:03.964091: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 10
# Out:
# Training DMN plus on babi task 10
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa10_indefinite-knowledge_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa10_indefinite-knowledge_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 22:09:26.082173: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 22:09:26.082197: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 10
# Out:
# Testing DMN plus on babi task 10
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa10_indefinite-knowledge_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa10_indefinite-knowledge_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 22:28:17.168555: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 22:28:17.168578: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_train.py -b 11
# Out:
# Training DMN plus on babi task 11
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa11_basic-coreference_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa11_basic-coreference_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 22:28:38.298715: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 22:28:38.298748: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 11
# Out:
# Testing DMN plus on babi task 11
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa11_basic-coreference_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa11_basic-coreference_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 22:44:07.511720: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 22:44:07.511754: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 12
# Out:
# Training DMN plus on babi task 12
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa12_conjunction_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa12_conjunction_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 22:44:30.389019: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 22:44:30.389047: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 12
# Out:
# Testing DMN plus on babi task 12
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa12_conjunction_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa12_conjunction_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 22:53:58.623744: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 22:53:58.623767: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 13
# Out:
# Training DMN plus on babi task 13
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa13_compound-coreference_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa13_compound-coreference_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-16 12:00:55.655307: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 12:00:55.655341: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 13
# Out:
# Testing DMN plus on babi task 13
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa13_compound-coreference_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa13_compound-coreference_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-16 12:08:41.414862: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 12:08:41.414883: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_train.py -b 14
# Out:
# Training DMN plus on babi task 14
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa14_time-reasoning_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa14_time-reasoning_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 23:01:07.740556: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 23:01:07.740586: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 14
# Out:
# Testing DMN plus on babi task 14
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa14_time-reasoning_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa14_time-reasoning_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 23:20:31.270558: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 23:20:31.270589: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 15
# Out:
# Training DMN plus on babi task 15
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa15_basic-deduction_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa15_basic-deduction_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 23:20:54.211785: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 23:20:54.211807: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 15
# Out:
# Testing DMN plus on babi task 15
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa15_basic-deduction_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa15_basic-deduction_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 23:28:47.248670: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 23:28:47.248692: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 16
# Out:
# Training DMN plus on babi task 16
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa16_basic-induction_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa16_basic-induction_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-15 23:29:12.539577: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 23:29:12.539611: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 16
# Out:
# Testing DMN plus on babi task 16
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa16_basic-induction_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa16_basic-induction_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-15 23:36:21.112601: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-15 23:36:21.112622: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 17
# Out:
# Training DMN plus on babi task 17
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa17_positional-reasoning_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa17_positional-reasoning_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-16 20:58:37.354533: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 20:58:37.354556: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 17
# Out:
# Testing DMN plus on babi task 17
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa17_positional-reasoning_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa17_positional-reasoning_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-16 21:04:55.122487: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 21:04:55.122510: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_train.py -b 18
# Out:
# Training DMN plus on babi task 18
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa18_size-reasoning_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa18_size-reasoning_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-16 12:23:01.937230: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 12:23:01.937254: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 18
# Out:
# Testing DMN plus on babi task 18
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa18_size-reasoning_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa18_size-reasoning_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-16 12:47:20.625984: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 12:47:20.626007: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 19
# Out:
# Training DMN plus on babi task 19
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa19_path-finding_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa19_path-finding_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-16 00:14:49.220778: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 00:14:49.220802: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 19
# Out:
# Testing DMN plus on babi task 19
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa19_path-finding_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa19_path-finding_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-16 00:51:16.094230: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 00:51:16.094254: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ==> restoring weights
# ...

# %%
# !python dmn_train.py -b 20
# Out:
# Training DMN plus on babi task 20
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa20_agents-motivations_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa20_agents-motivations_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# Starting run 0
# ==> initializing variables
# 2017-08-16 00:51:37.142258: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 00:51:37.142282: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python dmn_test.py -b 20
# Out:
# Testing DMN plus on babi task 20
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa20_agents-motivations_train.txt
# ==> Loading test from /Users/Home/ml/Dynamic-Memory-Networks-in-TensorFlow/data/en-10k/qa20_agents-motivations_test.txt
# ==> get train inputs
# ==> get test inputs
# ==> get question representation
# ==> get input representation
# ==> build episodic memory
# ==> generating episode 0
# ==> generating episode 1
# ==> generating episode 2
# ==> initializing variables
# 2017-08-16 01:57:16.134903: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-08-16 01:57:16.134925: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...
